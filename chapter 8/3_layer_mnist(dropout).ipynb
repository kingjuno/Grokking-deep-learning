# %%
import sys, numpy as np
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data() 
images, labels = (x_train[0:1000].reshape(1000,28*28)/255, y_train[0:1000]) # 1000 data for the sake of time
one_hot_labels = np.zeros((len(labels),10))

# %%
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

# %%
test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1
np.random.seed(1)
relu = lambda x:(x>=0) * x
relu2deriv = lambda x: x>=0
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 350, 40, 784, 10)
weights_0_1 = 0.2*np.random.random((pixels_per_image,hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1

# %%
for j in range(iterations):
    error, correct_cnt = (0.0, 0)

    for i in range(len(images)):
        layer_0 = images[i:i+1]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        drop_out_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= drop_out_mask*2
        layer_2 = np.dot(layer_1,weights_1_2)
        error += np.sum((labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == \
        np.argmax(labels[i:i+1]))
        layer_2_delta = (labels[i:i+1] - layer_2)
        layer_1_delta = layer_2_delta.dot(weights_1_2.T)\
        * relu2deriv(layer_1)
        layer_1 *= drop_out_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
        if(j%10 == 0):
            test_error = 0.0
            test_correct_cnt = 0

            for i in range(len(test_images)):
                layer_0 = test_images[i:i+1]
                layer_1 = relu(np.dot(layer_0,weights_0_1))
                layer_2 = np.dot(layer_1, weights_1_2)
                test_error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
                test_correct_cnt += int(np.argmax(layer_2) == \
                np.argmax(test_labels[i:i+1]))
            sys.stdout.write("\n" + \
            "I:" + str(j) + \
            " Test-Err:" + str(test_error/ float(len(test_images)))[0:5] +\
            " Test-Acc:" + str(test_correct_cnt/ float(len(test_images)))+\
            " Train-Err:" + str(error/ float(len(images)))[0:5] +\
            " Train-Acc:" + str(correct_cnt/ float(len(images))))
# Out:
# I:0 Test-Err:0.467 Test-Acc:0.7659 Train-Err:0.001 Train-Acc:0.0
# I:0 Test-Err:0.466 Test-Acc:0.7662 Train-Err:0.001 Train-Acc:0.001
# I:0 Test-Err:0.465 Test-Acc:0.7636 Train-Err:0.001 Train-Acc:0.002
# I:0 Test-Err:0.465 Test-Acc:0.7633 Train-Err:0.001 Train-Acc:0.003
# I:0 Test-Err:0.478 Test-Acc:0.7757 Train-Err:0.002 Train-Acc:0.004
# I:0 Test-Err:0.475 Test-Acc:0.7749 Train-Err:0.002 Train-Acc:0.005
# I:0 Test-Err:0.605 Test-Acc:0.6791 Train-Err:0.004 Train-Acc:0.006
# I:0 Test-Err:0.598 Test-Acc:0.6897 Train-Err:0.004 Train-Acc:0.006
# I:0 Test-Err:0.557 Test-Acc:0.7201 Train-Err:0.006 Train-Acc:0.006
# I:0 Test-Err:0.549 Test-Acc:0.7214 Train-Err:0.006 Train-Acc:0.007
# I:0 Test-Err:0.549 Test-Acc:0.7176 Train-Err:0.006 Train-Acc:0.008
# I:0 Test-Err:0.534 Test-Acc:0.7287 Train-Err:0.008 Train-Acc:0.008
# I:0 Test-Err:0.551 Test-Acc:0.7173 Train-Err:0.008 Train-Acc:0.009
# I:0 Test-Err:0.552 Test-Acc:0.7171 Train-Err:0.008 Train-Acc:0.01
# I:0 Test-Err:0.486 Test-Acc:0.8021 Train-Err:0.010 Train-Acc:0.01
# I:0 Test-Err:0.482 Test-Acc:0.8065 Train-Err:0.010 Train-Acc:0.011
# I:0 Test-Err:0.483 Test-Acc:0.8087 Train-Err:0.010 Train-Acc:0.012
# I:0 Test-Err:0.484 Test-Acc:0.805 Train-Err:0.010 Train-Acc:0.013
# I:0 Test-Err:0.477 Test-Acc:0.805 Train-Err:0.010 Train-Acc:0.014
# I:0 Test-Err:0.457 Test-Acc:0.7946 Train-Err:0.011 Train-Acc:0.015
# I:0 Test-Err:0.456 Test-Acc:0.7964 Train-Err:0.012 Train-Acc:0.016
# I:0 Test-Err:0.457 Test-Acc:0.7961 Train-Err:0.012 Train-Acc:0.017
# I:0 Test-Err:0.455 Test-Acc:0.7928 Train-Err:0.013 Train-Acc:0.017
# I:0 Test-Err:0.435 Test-Acc:0.7911 Train-Err:0.013 Train-Acc:0.018
# I:0 Test-Err:0.436 Test-Acc:0.7912 Train-Err:0.014 Train-Acc:0.018
# I:0 Test-Err:0.447 Test-Acc:0.794 Train-Err:0.015 Train-Acc:0.019
# I:0 Test-Err:0.446 Test-Acc:0.8043 Train-Err:0.015 Train-Acc:0.02
# I:0 Test-Err:0.717 Test-Acc:0.7293 Train-Err:0.019 Train-Acc:0.021
# I:0 Test-Err:0.716 Test-Acc:0.7304 Train-Err:0.020 Train-Acc:0.021
# I:0 Test-Err:0.708 Test-Acc:0.7337 Train-Err:0.021 Train-Acc:0.021
# I:0 Test-Err:0.665 Test-Acc:0.7345 Train-Err:0.023 Train-Acc:0.021
# I:0 Test-Err:0.663 Test-Acc:0.7339 Train-Err:0.024 Train-Acc:0.021
# I:0 Test-Err:0.663 Test-Acc:0.7342 Train-Err:0.025 Train-Acc:0.021
# I:0 Test-Err:0.666 Test-Acc:0.7201 Train-Err:0.026 Train-Acc:0.021
# I:0 Test-Err:0.668 Test-Acc:0.7189 Train-Err:0.026 Train-Acc:0.022
# I:0 Test-Err:0.663 Test-Acc:0.7262 Train-Err:0.027 Train-Acc:0.023
# I:0 Test-Err:0.664 Test-Acc:0.7265 Train-Err:0.027 Train-Acc:0.024
# I:0 Test-Err:0.668 Test-Acc:0.7263 Train-Err:0.027 Train-Acc:0.025
# I:0 Test-Err:0.660 Test-Acc:0.7313 Train-Err:0.027 Train-Acc:0.026
# I:0 Test-Err:0.661 Test-Acc:0.7317 Train-Err:0.027 Train-Acc:0.027
# I:0 Test-Err:0.659 Test-Acc:0.729 Train-Err:0.028 Train-Acc:0.028
# I:0 Test-Err:0.650 Test-Acc:0.7259 Train-Err:0.028 Train-Acc:0.029
# I:0 Test-Err:0.640 Test-Acc:0.7409 Train-Err:0.029 Train-Acc:0.029
# I:0 Test-Err:0.646 Test-Acc:0.7378 Train-Err:0.030 Train-Acc:0.029
# I:0 Test-Err:0.627 Test-Acc:0.7385 Train-Err:0.031 Train-Acc:0.029
# I:0 Test-Err:0.636 Test-Acc:0.7379 Train-Err:0.032 Train-Acc:0.03
# I:0 Test-Err:0.635 Test-Acc:0.7371 Train-Err:0.032 Train-Acc:0.031
# I:0 Test-Err:0.632 Test-Acc:0.7379 Train-Err:0.032 Train-Acc:0.032
# I:0 Test-Err:0.635 Test-Acc:0.7379 Train-Err:0.033 Train-Acc:0.032
# I:0 Test-Err:0.526 Test-Acc:0.766 Train-Err:0.037 Train-Acc:0.032
# I:0 Test-Err:0.522 Test-Acc:0.785 Train-Err:0.038 Train-Acc:0.032
# I:0 Test-Err:0.517 Test-Acc:0.785 Train-Err:0.038 Train-Acc:0.033
# I:0 Test-Err:0.511 Test-Acc:0.7899 Train-Err:0.039 Train-Acc:0.033
# I:0 Test-Err:0.512 Test-Acc:0.7903 Train-Err:0.039 Train-Acc:0.034
# I:0 Test-Err:0.513 Test-Acc:0.7899 Train-Err:0.040 Train-Acc:0.034
# I:0 Test-Err:0.507 Test-Acc:0.7824 Train-Err:0.041 Train-Acc:0.034
# I:0 Test-Err:0.509 Test-Acc:0.7831 Train-Err:0.041 Train-Acc:0.035
# I:0 Test-Err:0.494 Test-Acc:0.7753 Train-Err:0.042 Train-Acc:0.036
# I:0 Test-Err:0.501 Test-Acc:0.7794 Train-Err:0.042 Train-Acc:0.036
# I:0 Test-Err:0.494 Test-Acc:0.7805 Train-Err:0.043 Train-Acc:0.037
# I:0 Test-Err:0.497 Test-Acc:0.7803 Train-Err:0.043 Train-Acc:0.038
# I:0 Test-Err:0.501 Test-Acc:0.7806 Train-Err:0.043 Train-Acc:0.039
# I:0 Test-Err:0.503 Test-Acc:0.7801 Train-Err:0.044 Train-Acc:0.04
# I:0 Test-Err:0.500 Test-Acc:0.7792 Train-Err:0.044 Train-Acc:0.041
# I:0 Test-Err:0.501 Test-Acc:0.7788 Train-Err:0.044 Train-Acc:0.042
# I:0 Test-Err:0.505 Test-Acc:0.7641 Train-Err:0.044 Train-Acc:0.043
# I:0 Test-Err:0.519 Test-Acc:0.744 Train-Err:0.046 Train-Acc:0.044
# I:0 Test-Err:0.520 Test-Acc:0.7435 Train-Err:0.047 Train-Acc:0.045
# I:0 Test-Err:0.516 Test-Acc:0.7436 Train-Err:0.047 Train-Acc:0.046
# I:0 Test-Err:0.521 Test-Acc:0.7449 Train-Err:0.047 Train-Acc:0.047
# I:0 Test-Err:0.520 Test-Acc:0.7445 Train-Err:0.047 Train-Acc:0.048
# I:0 Test-Err:0.521 Test-Acc:0.7446 Train-Err:0.047 Train-Acc:0.049
# I:0 Test-Err:0.520 Test-Acc:0.7443 Train-Err:0.048 Train-Acc:0.05
# I:0 Test-Err:0.527 Test-Acc:0.7415 Train-Err:0.048 Train-Acc:0.051
# I:0 Test-Err:0.476 Test-Acc:0.7888 Train-Err:0.050 Train-Acc:0.052
# I:0 Test-Err:0.474 Test-Acc:0.7891 Train-Err:0.050 Train-Acc:0.053
# I:0 Test-Err:0.474 Test-Acc:0.791 Train-Err:0.051 Train-Acc:0.054
# I:0 Test-Err:0.473 Test-Acc:0.7908 Train-Err:0.051 Train-Acc:0.055
# I:0 Test-Err:0.474 Test-Acc:0.7909 Train-Err:0.052 Train-Acc:0.056
# I:0 Test-Err:0.472 Test-Acc:0.7896 Train-Err:0.052 Train-Acc:0.057
# I:0 Test-Err:0.472 Test-Acc:0.7883 Train-Err:0.053 Train-Acc:0.057
# I:0 Test-Err:0.469 Test-Acc:0.7886 Train-Err:0.053 Train-Acc:0.058
# I:0 Test-Err:0.471 Test-Acc:0.7887 Train-Err:0.054 Train-Acc:0.058
# I:0 Test-Err:0.458 Test-Acc:0.7971 Train-Err:0.055 Train-Acc:0.059
# I:0 Test-Err:0.467 Test-Acc:0.8016 Train-Err:0.056 Train-Acc:0.059
# I:0 Test-Err:0.460 Test-Acc:0.8018 Train-Err:0.056 Train-Acc:0.06
# I:0 Test-Err:0.451 Test-Acc:0.804 Train-Err:0.057 Train-Acc:0.061
# I:0 Test-Err:0.451 Test-Acc:0.8039 Train-Err:0.058 Train-Acc:0.061
# I:0 Test-Err:0.455 Test-Acc:0.8034 Train-Err:0.058 Train-Acc:0.062
# I:0 Test-Err:0.443 Test-Acc:0.8129 Train-Err:0.060 Train-Acc:0.063
# I:0 Test-Err:0.442 Test-Acc:0.8179 Train-Err:0.061 Train-Acc:0.064
# I:0 Test-Err:0.459 Test-Acc:0.787 Train-Err:0.061 Train-Acc:0.065
# I:0 Test-Err:0.461 Test-Acc:0.7576 Train-Err:0.061 Train-Acc:0.066
# I:0 Test-Err:0.460 Test-Acc:0.7582 Train-Err:0.061 Train-Acc:0.067
# I:0 Test-Err:0.460 Test-Acc:0.7581 Train-Err:0.062 Train-Acc:0.067
# I:0 Test-Err:0.458 Test-Acc:0.7592 Train-Err:0.062 Train-Acc:0.068
# I:0 Test-Err:0.444 Test-Acc:0.8021 Train-Err:0.063 Train-Acc:0.069
# I:0 Test-Err:0.445 Test-Acc:0.8014 Train-Err:0.063 Train-Acc:0.07
# I:0 Test-Err:0.457 Test-Acc:0.7986 Train-Err:0.065 Train-Acc:0.071
# I:0 Test-Err:0.461 Test-Acc:0.7986 Train-Err:0.065 Train-Acc:0.072
# I:0 Test-Err:0.453 Test-Acc:0.8023 Train-Err:0.066 Train-Acc:0.073
# I:0 Test-Err:0.456 Test-Acc:0.7928 Train-Err:0.066 Train-Acc:0.074
# I:0 Test-Err:0.501 Test-Acc:0.7845 Train-Err:0.068 Train-Acc:0.075
# I:0 Test-Err:0.513 Test-Acc:0.734 Train-Err:0.068 Train-Acc:0.076
# I:0 Test-Err:0.483 Test-Acc:0.7393 Train-Err:0.069 Train-Acc:0.076
# I:0 Test-Err:0.478 Test-Acc:0.7403 Train-Err:0.070 Train-Acc:0.077
# I:0 Test-Err:0.473 Test-Acc:0.7418 Train-Err:0.070 Train-Acc:0.078
# I:0 Test-Err:0.471 Test-Acc:0.7431 Train-Err:0.071 Train-Acc:0.078
# I:0 Test-Err:0.470 Test-Acc:0.744 Train-Err:0.071 Train-Acc:0.079
# I:0 Test-Err:0.492 Test-Acc:0.7292 Train-Err:0.074 Train-Acc:0.079
# I:0 Test-Err:0.491 Test-Acc:0.7293 Train-Err:0.075 Train-Acc:0.079
# I:0 Test-Err:0.486 Test-Acc:0.7312 Train-Err:0.076 Train-Acc:0.079
# I:0 Test-Err:0.482 Test-Acc:0.7313 Train-Err:0.076 Train-Acc:0.08
# I:0 Test-Err:0.480 Test-Acc:0.7314 Train-Err:0.076 Train-Acc:0.081
# I:0 Test-Err:0.480 Test-Acc:0.731 Train-Err:0.076 Train-Acc:0.082
# I:0 Test-Err:0.472 Test-Acc:0.7464 Train-Err:0.076 Train-Acc:0.083
# I:0 Test-Err:0.457 Test-Acc:0.7967 Train-Err:0.077 Train-Acc:0.084
# I:0 Test-Err:0.447 Test-Acc:0.7979 Train-Err:0.077 Train-Acc:0.085
# I:0 Test-Err:0.444 Test-Acc:0.799 Train-Err:0.077 Train-Acc:0.086
# I:0 Test-Err:0.441 Test-Acc:0.799 Train-Err:0.078 Train-Acc:0.087
# I:0 Test-Err:0.443 Test-Acc:0.7986 Train-Err:0.079 Train-Acc:0.087
# I:0 Test-Err:0.447 Test-Acc:0.798 Train-Err:0.079 Train-Acc:0.088
# I:0 Test-Err:0.457 Test-Acc:0.7903 Train-Err:0.079 Train-Acc:0.089
# I:0 Test-Err:0.486 Test-Acc:0.7812 Train-Err:0.080 Train-Acc:0.09
# I:0 Test-Err:0.489 Test-Acc:0.7777 Train-Err:0.080 Train-Acc:0.091
# I:0 Test-Err:0.473 Test-Acc:0.7782 Train-Err:0.081 Train-Acc:0.091
# I:0 Test-Err:0.462 Test-Acc:0.7837 Train-Err:0.081 Train-Acc:0.092
# I:0 Test-Err:0.461 Test-Acc:0.7839 Train-Err:0.081 Train-Acc:0.093
# I:0 Test-Err:0.452 Test-Acc:0.7912 Train-Err:0.082 Train-Acc:0.094
# I:0 Test-Err:0.455 Test-Acc:0.801 Train-Err:0.082 Train-Acc:0.094
# I:0 Test-Err:0.469 Test-Acc:0.7927 Train-Err:0.083 Train-Acc:0.095
# I:0 Test-Err:0.464 Test-Acc:0.793 Train-Err:0.083 Train-Acc:0.096
# I:0 Test-Err:0.468 Test-Acc:0.7881 Train-Err:0.084 Train-Acc:0.096
# I:0 Test-Err:0.435 Test-Acc:0.7948 Train-Err:0.085 Train-Acc:0.097
# I:0 Test-Err:0.471 Test-Acc:0.7404 Train-Err:0.086 Train-Acc:0.097
# I:0 Test-Err:0.466 Test-Acc:0.7428 Train-Err:0.087 Train-Acc:0.097
# I:0 Test-Err:0.468 Test-Acc:0.7466 Train-Err:0.088 Train-Acc:0.098
# I:0 Test-Err:0.462 Test-Acc:0.746 Train-Err:0.088 Train-Acc:0.099
# I:0 Test-Err:0.450 Test-Acc:0.7718 Train-Err:0.088 Train-Acc:0.1
# I:0 Test-Err:0.480 Test-Acc:0.7463 Train-Err:0.089 Train-Acc:0.101
# I:0 Test-Err:0.473 Test-Acc:0.7482 Train-Err:0.090 Train-Acc:0.101
# I:0 Test-Err:0.470 Test-Acc:0.7457 Train-Err:0.090 Train-Acc:0.102
# I:0 Test-Err:0.456 Test-Acc:0.757 Train-Err:0.091 Train-Acc:0.102
# I:0 Test-Err:0.459 Test-Acc:0.7582 Train-Err:0.092 Train-Acc:0.103
# I:0 Test-Err:0.455 Test-Acc:0.7602 Train-Err:0.092 Train-Acc:0.104
# I:0 Test-Err:0.465 Test-Acc:0.752 Train-Err:0.093 Train-Acc:0.105
# I:0 Test-Err:0.461 Test-Acc:0.7516 Train-Err:0.093 Train-Acc:0.106
# I:0 Test-Err:0.460 Test-Acc:0.7534 Train-Err:0.093 Train-Acc:0.107
# I:0 Test-Err:0.460 Test-Acc:0.7533 Train-Err:0.094 Train-Acc:0.107
# I:0 Test-Err:0.447 Test-Acc:0.7602 Train-Err:0.094 Train-Acc:0.108
# I:0 Test-Err:0.442 Test-Acc:0.7658 Train-Err:0.095 Train-Acc:0.108
# I:0 Test-Err:0.507 Test-Acc:0.6945 Train-Err:0.096 Train-Acc:0.109
# I:0 Test-Err:0.507 Test-Acc:0.6958 Train-Err:0.096 Train-Acc:0.11
# I:0 Test-Err:0.507 Test-Acc:0.6822 Train-Err:0.097 Train-Acc:0.111
# I:0 Test-Err:0.516 Test-Acc:0.6704 Train-Err:0.098 Train-Acc:0.111
# I:0 Test-Err:0.476 Test-Acc:0.7223 Train-Err:0.099 Train-Acc:0.111
# I:0 Test-Err:0.476 Test-Acc:0.7223 Train-Err:0.099 Train-Acc:0.112
# I:0 Test-Err:0.472 Test-Acc:0.7244 Train-Err:0.101 Train-Acc:0.112
# I:0 Test-Err:0.469 Test-Acc:0.7272 Train-Err:0.102 Train-Acc:0.112
# I:0 Test-Err:0.469 Test-Acc:0.731 Train-Err:0.102 Train-Acc:0.113
# I:0 Test-Err:0.470 Test-Acc:0.7271 Train-Err:0.103 Train-Acc:0.114
# I:0 Test-Err:0.469 Test-Acc:0.7296 Train-Err:0.104 Train-Acc:0.114
# I:0 Test-Err:0.476 Test-Acc:0.7195 Train-Err:0.104 Train-Acc:0.115
# I:0 Test-Err:0.491 Test-Acc:0.7125 Train-Err:0.104 Train-Acc:0.116
# I:0 Test-Err:0.475 Test-Acc:0.7245 Train-Err:0.105 Train-Acc:0.116
# I:0 Test-Err:0.459 Test-Acc:0.7402 Train-Err:0.106 Train-Acc:0.116
# I:0 Test-Err:0.452 Test-Acc:0.7438 Train-Err:0.107 Train-Acc:0.117
# I:0 Test-Err:0.449 Test-Acc:0.7425 Train-Err:0.107 Train-Acc:0.118
# I:0 Test-Err:0.446 Test-Acc:0.7438 Train-Err:0.108 Train-Acc:0.118
# I:0 Test-Err:0.481 Test-Acc:0.7392 Train-Err:0.109 Train-Acc:0.119
# I:0 Test-Err:0.480 Test-Acc:0.7409 Train-Err:0.109 Train-Acc:0.12
# I:0 Test-Err:0.479 Test-Acc:0.7425 Train-Err:0.109 Train-Acc:0.121
# I:0 Test-Err:0.483 Test-Acc:0.7377 Train-Err:0.109 Train-Acc:0.122
# I:0 Test-Err:0.489 Test-Acc:0.7386 Train-Err:0.110 Train-Acc:0.122
# I:0 Test-Err:0.486 Test-Acc:0.7405 Train-Err:0.110 Train-Acc:0.123
# I:0 Test-Err:0.498 Test-Acc:0.7428 Train-Err:0.111 Train-Acc:0.124
# I:0 Test-Err:0.494 Test-Acc:0.7586 Train-Err:0.111 Train-Acc:0.125
# I:0 Test-Err:0.491 Test-Acc:0.7599 Train-Err:0.111 Train-Acc:0.126
# I:0 Test-Err:0.491 Test-Acc:0.7612 Train-Err:0.112 Train-Acc:0.127
# I:0 Test-Err:0.473 Test-Acc:0.7699 Train-Err:0.113 Train-Acc:0.127
# I:0 Test-Err:0.473 Test-Acc:0.7707 Train-Err:0.114 Train-Acc:0.127
# I:0 Test-Err:0.468 Test-Acc:0.7726 Train-Err:0.115 Train-Acc:0.128
# I:0 Test-Err:0.460 Test-Acc:0.7763 Train-Err:0.115 Train-Acc:0.129
# I:0 Test-Err:0.505 Test-Acc:0.7807 Train-Err:0.116 Train-Acc:0.13
# I:0 Test-Err:0.505 Test-Acc:0.7805 Train-Err:0.116 Train-Acc:0.131
# I:0 Test-Err:0.504 Test-Acc:0.7324 Train-Err:0.117 Train-Acc:0.131
# I:0 Test-Err:0.503 Test-Acc:0.7337 Train-Err:0.117 Train-Acc:0.132
# I:0 Test-Err:0.501 Test-Acc:0.7347 Train-Err:0.117 Train-Acc:0.133
# I:0 Test-Err:0.489 Test-Acc:0.7416 Train-Err:0.118 Train-Acc:0.133
# I:0 Test-Err:0.490 Test-Acc:0.7418 Train-Err:0.119 Train-Acc:0.133
# I:0 Test-Err:0.492 Test-Acc:0.7401 Train-Err:0.120 Train-Acc:0.134
# I:0 Test-Err:0.495 Test-Acc:0.7376 Train-Err:0.120 Train-Acc:0.135
# I:0 Test-Err:0.478 Test-Acc:0.7429 Train-Err:0.120 Train-Acc:0.136
# I:0 Test-Err:0.481 Test-Acc:0.7411 Train-Err:0.120 Train-Acc:0.137
# I:0 Test-Err:0.466 Test-Acc:0.7469 Train-Err:0.121 Train-Acc:0.138
# I:0 Test-Err:0.465 Test-Acc:0.7495 Train-Err:0.122 Train-Acc:0.138
# I:0 Test-Err:0.467 Test-Acc:0.7429 Train-Err:0.122 Train-Acc:0.138
# I:0 Test-Err:0.463 Test-Acc:0.7357 Train-Err:0.123 Train-Acc:0.139
# I:0 Test-Err:0.461 Test-Acc:0.7358 Train-Err:0.123 Train-Acc:0.14
# I:0 Test-Err:0.464 Test-Acc:0.7368 Train-Err:0.123 Train-Acc:0.141
# I:0 Test-Err:0.465 Test-Acc:0.7373 Train-Err:0.124 Train-Acc:0.142
# I:0 Test-Err:0.465 Test-Acc:0.7376 Train-Err:0.125 Train-Acc:0.143
# I:0 Test-Err:0.468 Test-Acc:0.733 Train-Err:0.125 Train-Acc:0.144
# I:0 Test-Err:0.472 Test-Acc:0.7355 Train-Err:0.126 Train-Acc:0.145
# I:0 Test-Err:0.469 Test-Acc:0.7349 Train-Err:0.126 Train-Acc:0.146
# I:0 Test-Err:0.463 Test-Acc:0.7345 Train-Err:0.126 Train-Acc:0.147
# I:0 Test-Err:0.449 Test-Acc:0.7385 Train-Err:0.127 Train-Acc:0.148
# I:0 Test-Err:0.449 Test-Acc:0.7349 Train-Err:0.128 Train-Acc:0.148
# I:0 Test-Err:0.448 Test-Acc:0.7363 Train-Err:0.128 Train-Acc:0.149
# I:0 Test-Err:0.445 Test-Acc:0.7355 Train-Err:0.129 Train-Acc:0.15
# I:0 Test-Err:0.446 Test-Acc:0.7356 Train-Err:0.129 Train-Acc:0.151
# I:0 Test-Err:0.447 Test-Acc:0.7409 Train-Err:0.129 Train-Acc:0.152
# I:0 Test-Err:0.458 Test-Acc:0.7333 Train-Err:0.129 Train-Acc:0.153
# I:0 Test-Err:0.463 Test-Acc:0.7355 Train-Err:0.130 Train-Acc:0.154
# I:0 Test-Err:0.462 Test-Acc:0.7361 Train-Err:0.130 Train-Acc:0.155
# I:0 Test-Err:0.462 Test-Acc:0.7367 Train-Err:0.131 Train-Acc:0.155
# I:0 Test-Err:0.459 Test-Acc:0.7365 Train-Err:0.131 Train-Acc:0.156
# I:0 Test-Err:0.460 Test-Acc:0.7343 Train-Err:0.131 Train-Acc:0.157
# I:0 Test-Err:0.462 Test-Acc:0.7345 Train-Err:0.131 Train-Acc:0.158
# I:0 Test-Err:0.452 Test-Acc:0.7425 Train-Err:0.133 Train-Acc:0.158
# I:0 Test-Err:0.452 Test-Acc:0.7446 Train-Err:0.133 Train-Acc:0.159
# I:0 Test-Err:0.452 Test-Acc:0.744 Train-Err:0.133 Train-Acc:0.16
# I:0 Test-Err:0.450 Test-Acc:0.7444 Train-Err:0.133 Train-Acc:0.161
# I:0 Test-Err:0.460 Test-Acc:0.7394 Train-Err:0.133 Train-Acc:0.162
# I:0 Test-Err:0.460 Test-Acc:0.7394 Train-Err:0.134 Train-Acc:0.162
# I:0 Test-Err:0.464 Test-Acc:0.73 Train-Err:0.135 Train-Acc:0.163
# I:0 Test-Err:0.423 Test-Acc:0.7704 Train-Err:0.136 Train-Acc:0.163
# I:0 Test-Err:0.417 Test-Acc:0.7884 Train-Err:0.137 Train-Acc:0.163
# I:0 Test-Err:0.414 Test-Acc:0.7961 Train-Err:0.138 Train-Acc:0.163
# I:0 Test-Err:0.417 Test-Acc:0.7963 Train-Err:0.138 Train-Acc:0.164
# I:0 Test-Err:0.420 Test-Acc:0.8046 Train-Err:0.139 Train-Acc:0.165
# I:0 Test-Err:0.422 Test-Acc:0.8088 Train-Err:0.139 Train-Acc:0.166
# I:0 Test-Err:0.420 Test-Acc:0.8087 Train-Err:0.140 Train-Acc:0.166
# I:0 Test-Err:0.418 Test-Acc:0.8081 Train-Err:0.140 Train-Acc:0.167
# I:0 Test-Err:0.417 Test-Acc:0.8081 Train-Err:0.140 Train-Acc:0.168
# I:0 Test-Err:0.413 Test-Acc:0.8109 Train-Err:0.141 Train-Acc:0.169
# I:0 Test-Err:0.416 Test-Acc:0.8212 Train-Err:0.142 Train-Acc:0.169
# I:0 Test-Err:0.412 Test-Acc:0.8193 Train-Err:0.142 Train-Acc:0.17
# I:0 Test-Err:0.414 Test-Acc:0.8213 Train-Err:0.143 Train-Acc:0.171
# I:0 Test-Err:0.415 Test-Acc:0.8178 Train-Err:0.143 Train-Acc:0.171
# I:0 Test-Err:0.409 Test-Acc:0.8125 Train-Err:0.144 Train-Acc:0.172
# I:0 Test-Err:0.407 Test-Acc:0.8111 Train-Err:0.144 Train-Acc:0.173
# I:0 Test-Err:0.420 Test-Acc:0.8035 Train-Err:0.144 Train-Acc:0.174
# I:0 Test-Err:0.422 Test-Acc:0.8052 Train-Err:0.144 Train-Acc:0.175
# I:0 Test-Err:0.426 Test-Acc:0.7996 Train-Err:0.145 Train-Acc:0.176
# I:0 Test-Err:0.426 Test-Acc:0.7992 Train-Err:0.146 Train-Acc:0.176
# I:0 Test-Err:0.433 Test-Acc:0.8072 Train-Err:0.147 Train-Acc:0.177
# I:0 Test-Err:0.428 Test-Acc:0.7934 Train-Err:0.147 Train-Acc:0.178
# I:0 Test-Err:0.429 Test-Acc:0.794 Train-Err:0.148 Train-Acc:0.179
# I:0 Test-Err:0.429 Test-Acc:0.7939 Train-Err:0.149 Train-Acc:0.179
# I:0 Test-Err:0.426 Test-Acc:0.7956 Train-Err:0.150 Train-Acc:0.179
# I:0 Test-Err:0.429 Test-Acc:0.7964 Train-Err:0.150 Train-Acc:0.18
# I:0 Test-Err:0.427 Test-Acc:0.7938 Train-Err:0.150 Train-Acc:0.181
# I:0 Test-Err:0.431 Test-Acc:0.7934 Train-Err:0.151 Train-Acc:0.182
# I:0 Test-Err:0.431 Test-Acc:0.7938 Train-Err:0.152 Train-Acc:0.182
# I:0 Test-Err:0.428 Test-Acc:0.7956 Train-Err:0.152 Train-Acc:0.183
# I:0 Test-Err:0.428 Test-Acc:0.7958 Train-Err:0.153 Train-Acc:0.183
# I:0 Test-Err:0.433 Test-Acc:0.7929 Train-Err:0.153 Train-Acc:0.184
# I:0 Test-Err:0.434 Test-Acc:0.7952 Train-Err:0.153 Train-Acc:0.185
# I:0 Test-Err:0.434 Test-Acc:0.7953 Train-Err:0.154 Train-Acc:0.185
# I:0 Test-Err:0.432 Test-Acc:0.7959 Train-Err:0.155 Train-Acc:0.186
# I:0 Test-Err:0.431 Test-Acc:0.7972 Train-Err:0.155 Train-Acc:0.187
# I:0 Test-Err:0.442 Test-Acc:0.7968 Train-Err:0.156 Train-Acc:0.187
# I:0 Test-Err:0.437 Test-Acc:0.7949 Train-Err:0.156 Train-Acc:0.188
# I:0 Test-Err:0.441 Test-Acc:0.7879 Train-Err:0.157 Train-Acc:0.188
# I:0 Test-Err:0.437 Test-Acc:0.7819 Train-Err:0.158 Train-Acc:0.188
# I:0 Test-Err:0.465 Test-Acc:0.7804 Train-Err:0.159 Train-Acc:0.188
# I:0 Test-Err:0.468 Test-Acc:0.7703 Train-Err:0.160 Train-Acc:0.188
# I:0 Test-Err:0.478 Test-Acc:0.7685 Train-Err:0.161 Train-Acc:0.188
# I:0 Test-Err:0.478 Test-Acc:0.7687 Train-Err:0.161 Train-Acc:0.189
# I:0 Test-Err:0.477 Test-Acc:0.7666 Train-Err:0.162 Train-Acc:0.19
# I:0 Test-Err:0.477 Test-Acc:0.7722 Train-Err:0.162 Train-Acc:0.191
# I:0 Test-Err:0.466 Test-Acc:0.793 Train-Err:0.162 Train-Acc:0.191
# I:0 Test-Err:0.506 Test-Acc:0.7253 Train-Err:0.165 Train-Acc:0.192
# I:0 Test-Err:0.512 Test-Acc:0.707 Train-Err:0.165 Train-Acc:0.193
# I:0 Test-Err:0.512 Test-Acc:0.7059 Train-Err:0.165 Train-Acc:0.194
# I:0 Test-Err:0.510 Test-Acc:0.706 Train-Err:0.165 Train-Acc:0.195
# I:0 Test-Err:0.499 Test-Acc:0.7021 Train-Err:0.166 Train-Acc:0.196
# I:0 Test-Err:0.499 Test-Acc:0.6756 Train-Err:0.168 Train-Acc:0.196
# I:0 Test-Err:0.484 Test-Acc:0.6842 Train-Err:0.169 Train-Acc:0.197
# I:0 Test-Err:0.484 Test-Acc:0.6748 Train-Err:0.170 Train-Acc:0.197
# I:0 Test-Err:0.505 Test-Acc:0.6665 Train-Err:0.170 Train-Acc:0.198
# I:0 Test-Err:0.502 Test-Acc:0.6602 Train-Err:0.171 Train-Acc:0.199
# I:0 Test-Err:0.499 Test-Acc:0.6571 Train-Err:0.171 Train-Acc:0.2
# I:0 Test-Err:0.505 Test-Acc:0.6763 Train-Err:0.172 Train-Acc:0.2
# I:0 Test-Err:0.507 Test-Acc:0.6755 Train-Err:0.173 Train-Acc:0.2
# I:0 Test-Err:0.505 Test-Acc:0.6761 Train-Err:0.173 Train-Acc:0.201
# I:0 Test-Err:0.505 Test-Acc:0.6761 Train-Err:0.174 Train-Acc:0.201
# I:0 Test-Err:0.505 Test-Acc:0.6756 Train-Err:0.174 Train-Acc:0.202
# I:0 Test-Err:0.505 Test-Acc:0.676 Train-Err:0.174 Train-Acc:0.203
# I:0 Test-Err:0.509 Test-Acc:0.6746 Train-Err:0.175 Train-Acc:0.204
# I:0 Test-Err:0.500 Test-Acc:0.6795 Train-Err:0.176 Train-Acc:0.204
# I:0 Test-Err:0.497 Test-Acc:0.6916 Train-Err:0.177 Train-Acc:0.205
# I:0 Test-Err:0.497 Test-Acc:0.6888 Train-Err:0.178 Train-Acc:0.206
# I:0 Test-Err:0.499 Test-Acc:0.6905 Train-Err:0.178 Train-Acc:0.207
# I:0 Test-Err:0.476 Test-Acc:0.72 Train-Err:0.179 Train-Acc:0.207
# I:0 Test-Err:0.471 Test-Acc:0.7195 Train-Err:0.179 Train-Acc:0.208
# I:0 Test-Err:0.475 Test-Acc:0.7127 Train-Err:0.179 Train-Acc:0.209
# I:0 Test-Err:0.471 Test-Acc:0.7142 Train-Err:0.181 Train-Acc:0.209
# I:0 Test-Err:0.470 Test-Acc:0.7177 Train-Err:0.181 Train-Acc:0.21
# I:0 Test-Err:0.469 Test-Acc:0.7162 Train-Err:0.182 Train-Acc:0.21
# I:0 Test-Err:0.473 Test-Acc:0.7181 Train-Err:0.182 Train-Acc:0.211
# I:0 Test-Err:0.507 Test-Acc:0.6974 Train-Err:0.183 Train-Acc:0.212
# I:0 Test-Err:0.507 Test-Acc:0.6976 Train-Err:0.183 Train-Acc:0.213
# I:0 Test-Err:0.508 Test-Acc:0.691 Train-Err:0.183 Train-Acc:0.214
# I:0 Test-Err:0.506 Test-Acc:0.6878 Train-Err:0.184 Train-Acc:0.215
# I:0 Test-Err:0.474 Test-Acc:0.7553 Train-Err:0.185 Train-Acc:0.215
# I:0 Test-Err:0.483 Test-Acc:0.7787 Train-Err:0.185 Train-Acc:0.216
# I:0 Test-Err:1.147 Test-Acc:0.7172 Train-Err:0.193 Train-Acc:0.217
# I:0 Test-Err:1.133 Test-Acc:0.716 Train-Err:0.193 Train-Acc:0.218
# I:0 Test-Err:1.158 Test-Acc:0.7077 Train-Err:0.194 Train-Acc:0.219
# I:0 Test-Err:1.142 Test-Acc:0.7178 Train-Err:0.195 Train-Acc:0.219
# I:0 Test-Err:1.119 Test-Acc:0.7193 Train-Err:0.195 Train-Acc:0.22
# I:0 Test-Err:1.104 Test-Acc:0.7012 Train-Err:0.197 Train-Acc:0.22
# I:0 Test-Err:1.103 Test-Acc:0.7027 Train-Err:0.197 Train-Acc:0.221
# I:0 Test-Err:1.093 Test-Acc:0.7057 Train-Err:0.197 Train-Acc:0.222
# I:0 Test-Err:1.094 Test-Acc:0.7064 Train-Err:0.198 Train-Acc:0.222
# I:0 Test-Err:0.967 Test-Acc:0.7051 Train-Err:0.201 Train-Acc:0.222
# I:0 Test-Err:0.623 Test-Acc:0.6864 Train-Err:0.211 Train-Acc:0.222
# I:0 Test-Err:0.623 Test-Acc:0.6844 Train-Err:0.212 Train-Acc:0.222
# I:0 Test-Err:0.679 Test-Acc:0.664 Train-Err:0.213 Train-Acc:0.223
# I:0 Test-Err:0.672 Test-Acc:0.6646 Train-Err:0.213 Train-Acc:0.223
# I:0 Test-Err:0.677 Test-Acc:0.6502 Train-Err:0.214 Train-Acc:0.223
# I:0 Test-Err:0.669 Test-Acc:0.6496 Train-Err:0.215 Train-Acc:0.224
# I:0 Test-Err:0.664 Test-Acc:0.6622 Train-Err:0.216 Train-Acc:0.224
# I:0 Test-Err:0.663 Test-Acc:0.6621 Train-Err:0.217 Train-Acc:0.224
# I:0 Test-Err:0.629 Test-Acc:0.6816 Train-Err:0.218 Train-Acc:0.224
# I:0 Test-Err:0.629 Test-Acc:0.688 Train-Err:0.218 Train-Acc:0.225
# I:0 Test-Err:0.629 Test-Acc:0.6811 Train-Err:0.219 Train-Acc:0.226
# I:0 Test-Err:0.647 Test-Acc:0.6789 Train-Err:0.219 Train-Acc:0.227
# I:0 Test-Err:0.649 Test-Acc:0.6783 Train-Err:0.219 Train-Acc:0.228
# I:0 Test-Err:0.646 Test-Acc:0.6764 Train-Err:0.220 Train-Acc:0.229
# I:0 Test-Err:0.662 Test-Acc:0.6329 Train-Err:0.220 Train-Acc:0.229
# I:0 Test-Err:0.659 Test-Acc:0.6647 Train-Err:0.221 Train-Acc:0.23
# I:0 Test-Err:0.656 Test-Acc:0.6469 Train-Err:0.221 Train-Acc:0.231
# I:0 Test-Err:0.659 Test-Acc:0.6395 Train-Err:0.222 Train-Acc:0.232
# I:0 Test-Err:0.657 Test-Acc:0.6413 Train-Err:0.223 Train-Acc:0.232
# I:0 Test-Err:0.664 Test-Acc:0.6336 Train-Err:0.223 Train-Acc:0.233
# I:0 Test-Err:0.649 Test-Acc:0.6519 Train-Err:0.224 Train-Acc:0.233
# I:0 Test-Err:0.520 Test-Acc:0.7009 Train-Err:0.227 Train-Acc:0.233
# I:0 Test-Err:0.531 Test-Acc:0.7167 Train-Err:0.228 Train-Acc:0.233
# I:0 Test-Err:0.535 Test-Acc:0.719 Train-Err:0.228 Train-Acc:0.234
# I:0 Test-Err:0.523 Test-Acc:0.7337 Train-Err:0.229 Train-Acc:0.235
# I:0 Test-Err:0.517 Test-Acc:0.7369 Train-Err:0.229 Train-Acc:0.236
# I:0 Test-Err:0.538 Test-Acc:0.7241 Train-Err:0.230 Train-Acc:0.237
# I:0 Test-Err:0.529 Test-Acc:0.738 Train-Err:0.232 Train-Acc:0.237
# I:0 Test-Err:0.518 Test-Acc:0.7293 Train-Err:0.232 Train-Acc:0.238
# I:0 Test-Err:0.486 Test-Acc:0.7628 Train-Err:0.236 Train-Acc:0.238
# I:0 Test-Err:0.477 Test-Acc:0.7588 Train-Err:0.237 Train-Acc:0.239
# I:0 Test-Err:0.491 Test-Acc:0.745 Train-Err:0.237 Train-Acc:0.24
# I:0 Test-Err:0.491 Test-Acc:0.7365 Train-Err:0.238 Train-Acc:0.24
# I:0 Test-Err:0.483 Test-Acc:0.7463 Train-Err:0.239 Train-Acc:0.24
# I:0 Test-Err:0.486 Test-Acc:0.7438 Train-Err:0.241 Train-Acc:0.24
# I:0 Test-Err:0.482 Test-Acc:0.7475 Train-Err:0.242 Train-Acc:0.24
# I:0 Test-Err:0.476 Test-Acc:0.7644 Train-Err:0.243 Train-Acc:0.24
# I:0 Test-Err:0.477 Test-Acc:0.7646 Train-Err:0.243 Train-Acc:0.241
# I:0 Test-Err:0.476 Test-Acc:0.763 Train-Err:0.243 Train-Acc:0.242
# I:0 Test-Err:0.476 Test-Acc:0.7628 Train-Err:0.244 Train-Acc:0.242
# I:0 Test-Err:0.480 Test-Acc:0.7633 Train-Err:0.245 Train-Acc:0.243
# I:0 Test-Err:0.473 Test-Acc:0.7654 Train-Err:0.245 Train-Acc:0.244
# I:0 Test-Err:0.472 Test-Acc:0.7655 Train-Err:0.245 Train-Acc:0.245
# I:0 Test-Err:0.475 Test-Acc:0.7703 Train-Err:0.246 Train-Acc:0.245
# I:0 Test-Err:0.475 Test-Acc:0.7702 Train-Err:0.247 Train-Acc:0.245
# I:0 Test-Err:0.476 Test-Acc:0.7701 Train-Err:0.248 Train-Acc:0.246
# I:0 Test-Err:0.465 Test-Acc:0.7626 Train-Err:0.248 Train-Acc:0.247
# I:0 Test-Err:0.469 Test-Acc:0.754 Train-Err:0.249 Train-Acc:0.248
# I:0 Test-Err:0.464 Test-Acc:0.7543 Train-Err:0.249 Train-Acc:0.249
# I:0 Test-Err:0.464 Test-Acc:0.7543 Train-Err:0.250 Train-Acc:0.249
# I:0 Test-Err:0.449 Test-Acc:0.7612 Train-Err:0.251 Train-Acc:0.249
# I:0 Test-Err:0.468 Test-Acc:0.7525 Train-Err:0.251 Train-Acc:0.25
# I:0 Test-Err:0.462 Test-Acc:0.7699 Train-Err:0.253 Train-Acc:0.25
# I:0 Test-Err:0.458 Test-Acc:0.7729 Train-Err:0.253 Train-Acc:0.251
# I:0 Test-Err:0.452 Test-Acc:0.7713 Train-Err:0.253 Train-Acc:0.252
# I:0 Test-Err:0.481 Test-Acc:0.7306 Train-Err:0.254 Train-Acc:0.253
# I:0 Test-Err:0.481 Test-Acc:0.719 Train-Err:0.255 Train-Acc:0.254
# I:0 Test-Err:0.487 Test-Acc:0.7215 Train-Err:0.256 Train-Acc:0.254
# I:0 Test-Err:0.501 Test-Acc:0.7087 Train-Err:0.256 Train-Acc:0.254
# I:0 Test-Err:0.502 Test-Acc:0.7072 Train-Err:0.257 Train-Acc:0.255
# I:0 Test-Err:0.521 Test-Acc:0.7055 Train-Err:0.257 Train-Acc:0.256
# I:0 Test-Err:0.504 Test-Acc:0.732 Train-Err:0.258 Train-Acc:0.257
# I:0 Test-Err:0.492 Test-Acc:0.7488 Train-Err:0.258 Train-Acc:0.258
# I:0 Test-Err:0.474 Test-Acc:0.749 Train-Err:0.259 Train-Acc:0.259
# I:0 Test-Err:0.474 Test-Acc:0.749 Train-Err:0.259 Train-Acc:0.26
# I:0 Test-Err:0.525 Test-Acc:0.7124 Train-Err:0.259 Train-Acc:0.261
# I:0 Test-Err:0.535 Test-Acc:0.6967 Train-Err:0.260 Train-Acc:0.262
# I:0 Test-Err:0.557 Test-Acc:0.6785 Train-Err:0.261 Train-Acc:0.263
# I:0 Test-Err:0.544 Test-Acc:0.6828 Train-Err:0.262 Train-Acc:0.264
# I:0 Test-Err:0.558 Test-Acc:0.6876 Train-Err:0.263 Train-Acc:0.265
# I:0 Test-Err:0.555 Test-Acc:0.6887 Train-Err:0.263 Train-Acc:0.266
# I:0 Test-Err:0.520 Test-Acc:0.6984 Train-Err:0.264 Train-Acc:0.266
# I:0 Test-Err:0.516 Test-Acc:0.702 Train-Err:0.265 Train-Acc:0.266
# I:0 Test-Err:0.514 Test-Acc:0.7038 Train-Err:0.266 Train-Acc:0.266
# I:0 Test-Err:0.501 Test-Acc:0.7165 Train-Err:0.266 Train-Acc:0.267
# I:0 Test-Err:0.494 Test-Acc:0.712 Train-Err:0.268 Train-Acc:0.267
# I:0 Test-Err:0.490 Test-Acc:0.7161 Train-Err:0.268 Train-Acc:0.268
# I:0 Test-Err:0.490 Test-Acc:0.7179 Train-Err:0.269 Train-Acc:0.269
# I:0 Test-Err:0.493 Test-Acc:0.7108 Train-Err:0.270 Train-Acc:0.269
# I:0 Test-Err:0.502 Test-Acc:0.7108 Train-Err:0.270 Train-Acc:0.27
# I:0 Test-Err:0.566 Test-Acc:0.6691 Train-Err:0.272 Train-Acc:0.271
# I:0 Test-Err:0.558 Test-Acc:0.6713 Train-Err:0.273 Train-Acc:0.272
# I:0 Test-Err:0.550 Test-Acc:0.6783 Train-Err:0.274 Train-Acc:0.272
# I:0 Test-Err:0.555 Test-Acc:0.6756 Train-Err:0.274 Train-Acc:0.273
# I:0 Test-Err:0.527 Test-Acc:0.7162 Train-Err:0.275 Train-Acc:0.273
# I:0 Test-Err:0.528 Test-Acc:0.7113 Train-Err:0.275 Train-Acc:0.274
# I:0 Test-Err:0.529 Test-Acc:0.6879 Train-Err:0.276 Train-Acc:0.274
# I:0 Test-Err:0.527 Test-Acc:0.6903 Train-Err:0.276 Train-Acc:0.275
# I:0 Test-Err:0.499 Test-Acc:0.7321 Train-Err:0.277 Train-Acc:0.276
# I:0 Test-Err:0.512 Test-Acc:0.721 Train-Err:0.277 Train-Acc:0.277
# I:0 Test-Err:0.480 Test-Acc:0.7297 Train-Err:0.278 Train-Acc:0.277
# I:0 Test-Err:0.478 Test-Acc:0.716 Train-Err:0.278 Train-Acc:0.278
# I:0 Test-Err:0.479 Test-Acc:0.7163 Train-Err:0.279 Train-Acc:0.279
# I:0 Test-Err:0.471 Test-Acc:0.7397 Train-Err:0.279 Train-Acc:0.28
# I:0 Test-Err:0.467 Test-Acc:0.7437 Train-Err:0.280 Train-Acc:0.281
# I:0 Test-Err:0.467 Test-Acc:0.7425 Train-Err:0.280 Train-Acc:0.282
# I:0 Test-Err:0.475 Test-Acc:0.7517 Train-Err:0.280 Train-Acc:0.282
# I:0 Test-Err:0.475 Test-Acc:0.7513 Train-Err:0.281 Train-Acc:0.282
# I:0 Test-Err:0.467 Test-Acc:0.7554 Train-Err:0.282 Train-Acc:0.282
# I:0 Test-Err:0.464 Test-Acc:0.7576 Train-Err:0.283 Train-Acc:0.283
# I:0 Test-Err:0.465 Test-Acc:0.7561 Train-Err:0.284 Train-Acc:0.283
# I:0 Test-Err:0.458 Test-Acc:0.7558 Train-Err:0.284 Train-Acc:0.284
# I:0 Test-Err:0.458 Test-Acc:0.7597 Train-Err:0.284 Train-Acc:0.285
# I:0 Test-Err:0.500 Test-Acc:0.7185 Train-Err:0.285 Train-Acc:0.286
# I:0 Test-Err:0.488 Test-Acc:0.7263 Train-Err:0.285 Train-Acc:0.287
# I:0 Test-Err:0.488 Test-Acc:0.7262 Train-Err:0.286 Train-Acc:0.287
# I:0 Test-Err:0.484 Test-Acc:0.7124 Train-Err:0.287 Train-Acc:0.288
# I:0 Test-Err:0.470 Test-Acc:0.7248 Train-Err:0.287 Train-Acc:0.288
# I:0 Test-Err:0.484 Test-Acc:0.7336 Train-Err:0.288 Train-Acc:0.288
# I:0 Test-Err:0.482 Test-Acc:0.7335 Train-Err:0.288 Train-Acc:0.289
# I:0 Test-Err:0.476 Test-Acc:0.7257 Train-Err:0.289 Train-Acc:0.29
# I:0 Test-Err:0.472 Test-Acc:0.7311 Train-Err:0.289 Train-Acc:0.291
# I:0 Test-Err:0.449 Test-Acc:0.7596 Train-Err:0.289 Train-Acc:0.292
# I:0 Test-Err:0.432 Test-Acc:0.7676 Train-Err:0.290 Train-Acc:0.293
# I:0 Test-Err:0.429 Test-Acc:0.77 Train-Err:0.290 Train-Acc:0.294
# I:0 Test-Err:0.429 Test-Acc:0.7696 Train-Err:0.291 Train-Acc:0.294
# I:0 Test-Err:0.441 Test-Acc:0.7582 Train-Err:0.291 Train-Acc:0.295
# I:0 Test-Err:0.435 Test-Acc:0.7612 Train-Err:0.292 Train-Acc:0.296
# I:0 Test-Err:0.434 Test-Acc:0.7687 Train-Err:0.293 Train-Acc:0.296
# I:0 Test-Err:0.436 Test-Acc:0.7682 Train-Err:0.293 Train-Acc:0.297
# I:0 Test-Err:0.430 Test-Acc:0.7718 Train-Err:0.294 Train-Acc:0.297
# I:0 Test-Err:0.428 Test-Acc:0.7697 Train-Err:0.294 Train-Acc:0.298
# I:0 Test-Err:0.431 Test-Acc:0.7695 Train-Err:0.295 Train-Acc:0.299
# I:0 Test-Err:0.427 Test-Acc:0.7692 Train-Err:0.295 Train-Acc:0.3
# I:0 Test-Err:0.429 Test-Acc:0.7643 Train-Err:0.295 Train-Acc:0.301
# I:0 Test-Err:0.432 Test-Acc:0.7623 Train-Err:0.295 Train-Acc:0.302
# I:0 Test-Err:0.427 Test-Acc:0.7644 Train-Err:0.297 Train-Acc:0.302
# I:0 Test-Err:0.427 Test-Acc:0.7645 Train-Err:0.298 Train-Acc:0.302
# I:0 Test-Err:0.429 Test-Acc:0.7794 Train-Err:0.299 Train-Acc:0.302
# I:0 Test-Err:0.424 Test-Acc:0.7807 Train-Err:0.299 Train-Acc:0.303
# I:0 Test-Err:0.421 Test-Acc:0.7839 Train-Err:0.300 Train-Acc:0.304
# I:0 Test-Err:0.421 Test-Acc:0.7853 Train-Err:0.300 Train-Acc:0.304
# I:0 Test-Err:0.421 Test-Acc:0.7853 Train-Err:0.301 Train-Acc:0.304
# I:0 Test-Err:0.416 Test-Acc:0.7862 Train-Err:0.302 Train-Acc:0.305
# I:0 Test-Err:0.416 Test-Acc:0.7863 Train-Err:0.303 Train-Acc:0.305
# I:0 Test-Err:0.415 Test-Acc:0.7876 Train-Err:0.303 Train-Acc:0.306
# I:0 Test-Err:0.416 Test-Acc:0.7875 Train-Err:0.304 Train-Acc:0.307
# I:0 Test-Err:0.431 Test-Acc:0.7886 Train-Err:0.304 Train-Acc:0.308
# I:0 Test-Err:0.429 Test-Acc:0.7859 Train-Err:0.304 Train-Acc:0.309
# I:0 Test-Err:0.429 Test-Acc:0.7881 Train-Err:0.305 Train-Acc:0.309
# I:0 Test-Err:0.430 Test-Acc:0.7876 Train-Err:0.306 Train-Acc:0.31
# I:0 Test-Err:0.432 Test-Acc:0.798 Train-Err:0.306 Train-Acc:0.31
# I:0 Test-Err:0.429 Test-Acc:0.788 Train-Err:0.307 Train-Acc:0.311
# I:0 Test-Err:0.425 Test-Acc:0.7918 Train-Err:0.307 Train-Acc:0.312
# I:0 Test-Err:0.423 Test-Acc:0.7915 Train-Err:0.307 Train-Acc:0.313
# I:0 Test-Err:0.422 Test-Acc:0.7921 Train-Err:0.307 Train-Acc:0.314
# I:0 Test-Err:0.426 Test-Acc:0.7931 Train-Err:0.308 Train-Acc:0.315
# I:0 Test-Err:0.424 Test-Acc:0.7939 Train-Err:0.308 Train-Acc:0.316
# I:0 Test-Err:0.413 Test-Acc:0.7967 Train-Err:0.308 Train-Acc:0.317
# I:0 Test-Err:0.416 Test-Acc:0.7951 Train-Err:0.308 Train-Acc:0.318
# I:0 Test-Err:0.413 Test-Acc:0.7971 Train-Err:0.309 Train-Acc:0.318
# I:0 Test-Err:0.411 Test-Acc:0.7877 Train-Err:0.310 Train-Acc:0.319
# I:0 Test-Err:0.413 Test-Acc:0.7936 Train-Err:0.311 Train-Acc:0.319
# I:0 Test-Err:0.413 Test-Acc:0.793 Train-Err:0.312 Train-Acc:0.319
# I:0 Test-Err:0.411 Test-Acc:0.801 Train-Err:0.313 Train-Acc:0.319
# I:0 Test-Err:0.406 Test-Acc:0.8006 Train-Err:0.313 Train-Acc:0.32
# I:0 Test-Err:0.515 Test-Acc:0.7462 Train-Err:0.315 Train-Acc:0.321
# I:0 Test-Err:0.512 Test-Acc:0.7457 Train-Err:0.316 Train-Acc:0.321
# I:0 Test-Err:0.512 Test-Acc:0.7514 Train-Err:0.316 Train-Acc:0.322
# I:0 Test-Err:0.513 Test-Acc:0.7515 Train-Err:0.317 Train-Acc:0.322
# I:0 Test-Err:0.513 Test-Acc:0.7516 Train-Err:0.318 Train-Acc:0.322
# I:0 Test-Err:0.517 Test-Acc:0.75 Train-Err:0.318 Train-Acc:0.323
# I:0 Test-Err:0.473 Test-Acc:0.7522 Train-Err:0.320 Train-Acc:0.323
# I:0 Test-Err:0.474 Test-Acc:0.752 Train-Err:0.320 Train-Acc:0.324
# I:0 Test-Err:0.490 Test-Acc:0.7524 Train-Err:0.321 Train-Acc:0.325
# I:0 Test-Err:0.518 Test-Acc:0.7435 Train-Err:0.321 Train-Acc:0.326
# I:0 Test-Err:0.515 Test-Acc:0.7431 Train-Err:0.321 Train-Acc:0.327
# I:0 Test-Err:0.516 Test-Acc:0.7349 Train-Err:0.322 Train-Acc:0.328
# I:0 Test-Err:0.491 Test-Acc:0.7413 Train-Err:0.322 Train-Acc:0.329
# I:0 Test-Err:0.472 Test-Acc:0.7412 Train-Err:0.323 Train-Acc:0.33
# I:0 Test-Err:0.472 Test-Acc:0.7414 Train-Err:0.324 Train-Acc:0.33
# I:0 Test-Err:0.460 Test-Acc:0.742 Train-Err:0.324 Train-Acc:0.331
# I:0 Test-Err:0.461 Test-Acc:0.7414 Train-Err:0.324 Train-Acc:0.332
# I:0 Test-Err:0.466 Test-Acc:0.7407 Train-Err:0.325 Train-Acc:0.332
# I:0 Test-Err:0.475 Test-Acc:0.728 Train-Err:0.325 Train-Acc:0.333
# I:0 Test-Err:0.475 Test-Acc:0.7293 Train-Err:0.325 Train-Acc:0.334
# I:0 Test-Err:0.495 Test-Acc:0.731 Train-Err:0.327 Train-Acc:0.334
# I:0 Test-Err:0.495 Test-Acc:0.7311 Train-Err:0.327 Train-Acc:0.335
# I:0 Test-Err:0.479 Test-Acc:0.7662 Train-Err:0.328 Train-Acc:0.335
# I:0 Test-Err:0.468 Test-Acc:0.7868 Train-Err:0.329 Train-Acc:0.335
# I:0 Test-Err:0.467 Test-Acc:0.7882 Train-Err:0.329 Train-Acc:0.336
# I:0 Test-Err:0.510 Test-Acc:0.7659 Train-Err:0.330 Train-Acc:0.337
# I:0 Test-Err:0.512 Test-Acc:0.7623 Train-Err:0.331 Train-Acc:0.338
# I:0 Test-Err:0.507 Test-Acc:0.7465 Train-Err:0.332 Train-Acc:0.339
# I:0 Test-Err:0.496 Test-Acc:0.7498 Train-Err:0.333 Train-Acc:0.339
# I:0 Test-Err:0.496 Test-Acc:0.7497 Train-Err:0.334 Train-Acc:0.339
# I:0 Test-Err:0.501 Test-Acc:0.7572 Train-Err:0.335 Train-Acc:0.339
# I:0 Test-Err:0.489 Test-Acc:0.7631 Train-Err:0.335 Train-Acc:0.34
# I:0 Test-Err:0.496 Test-Acc:0.7599 Train-Err:0.336 Train-Acc:0.341
# I:0 Test-Err:0.490 Test-Acc:0.7686 Train-Err:0.336 Train-Acc:0.342
# I:0 Test-Err:0.492 Test-Acc:0.7733 Train-Err:0.336 Train-Acc:0.343
# I:0 Test-Err:0.492 Test-Acc:0.77 Train-Err:0.337 Train-Acc:0.343
# I:0 Test-Err:0.491 Test-Acc:0.7701 Train-Err:0.338 Train-Acc:0.343
# I:0 Test-Err:0.488 Test-Acc:0.7756 Train-Err:0.339 Train-Acc:0.343
# I:0 Test-Err:0.477 Test-Acc:0.7845 Train-Err:0.340 Train-Acc:0.344
# I:0 Test-Err:0.477 Test-Acc:0.7798 Train-Err:0.341 Train-Acc:0.344
# I:0 Test-Err:0.477 Test-Acc:0.7739 Train-Err:0.341 Train-Acc:0.345
# I:0 Test-Err:0.484 Test-Acc:0.7749 Train-Err:0.341 Train-Acc:0.346
# I:0 Test-Err:0.485 Test-Acc:0.7705 Train-Err:0.342 Train-Acc:0.347
# I:0 Test-Err:0.465 Test-Acc:0.7856 Train-Err:0.343 Train-Acc:0.347
# I:0 Test-Err:0.464 Test-Acc:0.7863 Train-Err:0.344 Train-Acc:0.348
# I:0 Test-Err:0.445 Test-Acc:0.7865 Train-Err:0.345 Train-Acc:0.349
# I:0 Test-Err:0.502 Test-Acc:0.7519 Train-Err:0.346 Train-Acc:0.35
# I:0 Test-Err:0.496 Test-Acc:0.7545 Train-Err:0.347 Train-Acc:0.35
# I:0 Test-Err:0.496 Test-Acc:0.7546 Train-Err:0.348 Train-Acc:0.35
# I:0 Test-Err:0.491 Test-Acc:0.7524 Train-Err:0.348 Train-Acc:0.351
# I:0 Test-Err:0.487 Test-Acc:0.7524 Train-Err:0.349 Train-Acc:0.352
# I:0 Test-Err:0.454 Test-Acc:0.7926 Train-Err:0.349 Train-Acc:0.353
# I:0 Test-Err:0.454 Test-Acc:0.7917 Train-Err:0.350 Train-Acc:0.354
# I:0 Test-Err:0.455 Test-Acc:0.7921 Train-Err:0.350 Train-Acc:0.355
# I:0 Test-Err:0.449 Test-Acc:0.7934 Train-Err:0.351 Train-Acc:0.355
# I:0 Test-Err:0.441 Test-Acc:0.7918 Train-Err:0.351 Train-Acc:0.356
# I:0 Test-Err:0.444 Test-Acc:0.7921 Train-Err:0.351 Train-Acc:0.357
# I:0 Test-Err:0.453 Test-Acc:0.7888 Train-Err:0.351 Train-Acc:0.358
# I:0 Test-Err:0.457 Test-Acc:0.7874 Train-Err:0.352 Train-Acc:0.358
# I:0 Test-Err:0.457 Test-Acc:0.7887 Train-Err:0.353 Train-Acc:0.358
# I:0 Test-Err:0.456 Test-Acc:0.7891 Train-Err:0.353 Train-Acc:0.359
# I:0 Test-Err:0.473 Test-Acc:0.776 Train-Err:0.354 Train-Acc:0.359
# I:0 Test-Err:0.479 Test-Acc:0.7622 Train-Err:0.354 Train-Acc:0.36
# I:0 Test-Err:0.480 Test-Acc:0.7621 Train-Err:0.355 Train-Acc:0.361
# I:0 Test-Err:0.466 Test-Acc:0.7624 Train-Err:0.355 Train-Acc:0.362
# I:0 Test-Err:0.462 Test-Acc:0.7688 Train-Err:0.356 Train-Acc:0.362
# I:0 Test-Err:0.462 Test-Acc:0.7694 Train-Err:0.357 Train-Acc:0.362
# I:0 Test-Err:0.436 Test-Acc:0.7971 Train-Err:0.357 Train-Acc:0.362
# I:0 Test-Err:0.436 Test-Acc:0.7968 Train-Err:0.358 Train-Acc:0.363
# I:0 Test-Err:0.433 Test-Acc:0.7996 Train-Err:0.358 Train-Acc:0.364
# I:0 Test-Err:0.443 Test-Acc:0.7834 Train-Err:0.358 Train-Acc:0.365
# I:0 Test-Err:0.441 Test-Acc:0.7812 Train-Err:0.359 Train-Acc:0.366
# I:0 Test-Err:0.422 Test-Acc:0.8045 Train-Err:0.360 Train-Acc:0.366
# I:0 Test-Err:0.436 Test-Acc:0.803 Train-Err:0.361 Train-Acc:0.367
# I:0 Test-Err:0.437 Test-Acc:0.803 Train-Err:0.361 Train-Acc:0.368
# I:0 Test-Err:0.443 Test-Acc:0.7944 Train-Err:0.361 Train-Acc:0.369
# I:0 Test-Err:0.440 Test-Acc:0.7948 Train-Err:0.361 Train-Acc:0.37
# I:0 Test-Err:0.441 Test-Acc:0.7964 Train-Err:0.361 Train-Acc:0.371
# I:0 Test-Err:0.444 Test-Acc:0.7942 Train-Err:0.361 Train-Acc:0.372
# I:0 Test-Err:0.451 Test-Acc:0.7946 Train-Err:0.362 Train-Acc:0.373
# I:0 Test-Err:0.453 Test-Acc:0.7915 Train-Err:0.362 Train-Acc:0.374
# I:0 Test-Err:0.453 Test-Acc:0.7918 Train-Err:0.363 Train-Acc:0.374
# I:0 Test-Err:0.450 Test-Acc:0.7892 Train-Err:0.363 Train-Acc:0.375
# I:0 Test-Err:0.448 Test-Acc:0.7937 Train-Err:0.364 Train-Acc:0.376
# I:0 Test-Err:0.453 Test-Acc:0.7966 Train-Err:0.365 Train-Acc:0.376
# I:0 Test-Err:0.448 Test-Acc:0.7929 Train-Err:0.366 Train-Acc:0.376
# I:0 Test-Err:0.440 Test-Acc:0.8006 Train-Err:0.367 Train-Acc:0.376
# I:0 Test-Err:0.435 Test-Acc:0.8032 Train-Err:0.367 Train-Acc:0.377
# I:0 Test-Err:0.428 Test-Acc:0.8049 Train-Err:0.368 Train-Acc:0.378
# I:0 Test-Err:0.434 Test-Acc:0.8065 Train-Err:0.368 Train-Acc:0.379
# I:0 Test-Err:0.425 Test-Acc:0.8079 Train-Err:0.369 Train-Acc:0.38
# I:0 Test-Err:0.428 Test-Acc:0.8093 Train-Err:0.369 Train-Acc:0.381
# I:0 Test-Err:0.429 Test-Acc:0.8075 Train-Err:0.370 Train-Acc:0.381
# I:0 Test-Err:0.426 Test-Acc:0.8105 Train-Err:0.371 Train-Acc:0.382
# I:0 Test-Err:0.434 Test-Acc:0.8145 Train-Err:0.371 Train-Acc:0.383
# I:0 Test-Err:0.427 Test-Acc:0.8198 Train-Err:0.372 Train-Acc:0.384
# I:0 Test-Err:0.433 Test-Acc:0.8199 Train-Err:0.372 Train-Acc:0.385
# I:0 Test-Err:0.433 Test-Acc:0.8196 Train-Err:0.373 Train-Acc:0.385
# I:0 Test-Err:0.429 Test-Acc:0.8184 Train-Err:0.373 Train-Acc:0.386
# I:0 Test-Err:0.429 Test-Acc:0.8159 Train-Err:0.374 Train-Acc:0.386
# I:0 Test-Err:0.427 Test-Acc:0.8176 Train-Err:0.374 Train-Acc:0.387
# I:0 Test-Err:0.427 Test-Acc:0.8158 Train-Err:0.375 Train-Acc:0.388
# I:0 Test-Err:0.434 Test-Acc:0.8111 Train-Err:0.376 Train-Acc:0.389
# I:0 Test-Err:0.435 Test-Acc:0.8102 Train-Err:0.376 Train-Acc:0.39
# I:0 Test-Err:0.440 Test-Acc:0.8109 Train-Err:0.376 Train-Acc:0.391
# I:0 Test-Err:0.434 Test-Acc:0.8132 Train-Err:0.377 Train-Acc:0.392
# I:0 Test-Err:0.434 Test-Acc:0.813 Train-Err:0.378 Train-Acc:0.392
# I:0 Test-Err:0.436 Test-Acc:0.8111 Train-Err:0.378 Train-Acc:0.393
# I:0 Test-Err:0.432 Test-Acc:0.8112 Train-Err:0.378 Train-Acc:0.394
# I:0 Test-Err:0.432 Test-Acc:0.8111 Train-Err:0.379 Train-Acc:0.394
# I:0 Test-Err:0.436 Test-Acc:0.8123 Train-Err:0.379 Train-Acc:0.395
# I:0 Test-Err:0.436 Test-Acc:0.8107 Train-Err:0.380 Train-Acc:0.396
# I:0 Test-Err:0.437 Test-Acc:0.8124 Train-Err:0.381 Train-Acc:0.396
# I:0 Test-Err:0.445 Test-Acc:0.7907 Train-Err:0.381 Train-Acc:0.397
# I:0 Test-Err:0.447 Test-Acc:0.7929 Train-Err:0.382 Train-Acc:0.397
# I:0 Test-Err:0.437 Test-Acc:0.7946 Train-Err:0.383 Train-Acc:0.397
# I:0 Test-Err:0.437 Test-Acc:0.7954 Train-Err:0.383 Train-Acc:0.398
# I:0 Test-Err:0.416 Test-Acc:0.7999 Train-Err:0.384 Train-Acc:0.399
# I:0 Test-Err:0.408 Test-Acc:0.8 Train-Err:0.384 Train-Acc:0.4
# I:0 Test-Err:0.405 Test-Acc:0.8 Train-Err:0.385 Train-Acc:0.401
# I:0 Test-Err:0.405 Test-Acc:0.8001 Train-Err:0.386 Train-Acc:0.401
# I:0 Test-Err:0.403 Test-Acc:0.7964 Train-Err:0.386 Train-Acc:0.402
# I:0 Test-Err:0.403 Test-Acc:0.796 Train-Err:0.386 Train-Acc:0.403
# I:0 Test-Err:0.403 Test-Acc:0.7961 Train-Err:0.386 Train-Acc:0.404
# I:0 Test-Err:0.398 Test-Acc:0.7939 Train-Err:0.387 Train-Acc:0.405
# I:0 Test-Err:0.404 Test-Acc:0.8024 Train-Err:0.388 Train-Acc:0.405
# I:0 Test-Err:0.403 Test-Acc:0.8038 Train-Err:0.389 Train-Acc:0.405
# I:0 Test-Err:0.397 Test-Acc:0.8023 Train-Err:0.389 Train-Acc:0.406
# I:0 Test-Err:0.389 Test-Acc:0.8112 Train-Err:0.390 Train-Acc:0.407
# I:0 Test-Err:0.403 Test-Acc:0.8103 Train-Err:0.391 Train-Acc:0.408
# I:0 Test-Err:0.406 Test-Acc:0.8072 Train-Err:0.391 Train-Acc:0.409
# I:0 Test-Err:0.408 Test-Acc:0.8073 Train-Err:0.391 Train-Acc:0.41
# I:0 Test-Err:0.413 Test-Acc:0.8058 Train-Err:0.391 Train-Acc:0.411
# I:0 Test-Err:0.413 Test-Acc:0.8062 Train-Err:0.392 Train-Acc:0.411
# I:0 Test-Err:0.413 Test-Acc:0.8065 Train-Err:0.393 Train-Acc:0.411
# I:0 Test-Err:0.440 Test-Acc:0.8079 Train-Err:0.394 Train-Acc:0.412
# I:0 Test-Err:0.439 Test-Acc:0.8082 Train-Err:0.395 Train-Acc:0.413
# I:0 Test-Err:0.443 Test-Acc:0.8172 Train-Err:0.396 Train-Acc:0.413
# I:0 Test-Err:0.433 Test-Acc:0.8177 Train-Err:0.396 Train-Acc:0.414
# I:0 Test-Err:0.434 Test-Acc:0.8169 Train-Err:0.397 Train-Acc:0.414
# I:0 Test-Err:0.448 Test-Acc:0.8058 Train-Err:0.398 Train-Acc:0.414
# I:0 Test-Err:0.450 Test-Acc:0.8102 Train-Err:0.398 Train-Acc:0.415
# I:0 Test-Err:0.444 Test-Acc:0.8127 Train-Err:0.398 Train-Acc:0.416
# I:0 Test-Err:0.450 Test-Acc:0.8141 Train-Err:0.398 Train-Acc:0.417
# I:0 Test-Err:0.445 Test-Acc:0.8107 Train-Err:0.399 Train-Acc:0.418
# I:0 Test-Err:0.443 Test-Acc:0.8094 Train-Err:0.399 Train-Acc:0.419
# I:0 Test-Err:0.444 Test-Acc:0.8095 Train-Err:0.400 Train-Acc:0.419
# I:0 Test-Err:0.444 Test-Acc:0.8103 Train-Err:0.401 Train-Acc:0.419
# I:0 Test-Err:0.444 Test-Acc:0.8096 Train-Err:0.401 Train-Acc:0.42
# I:0 Test-Err:0.445 Test-Acc:0.8095 Train-Err:0.401 Train-Acc:0.421
# I:0 Test-Err:0.450 Test-Acc:0.806 Train-Err:0.402 Train-Acc:0.422
# I:0 Test-Err:0.455 Test-Acc:0.8005 Train-Err:0.403 Train-Acc:0.422
# I:0 Test-Err:0.484 Test-Acc:0.7589 Train-Err:0.404 Train-Acc:0.422
# I:0 Test-Err:0.480 Test-Acc:0.7594 Train-Err:0.404 Train-Acc:0.423
# I:0 Test-Err:0.474 Test-Acc:0.761 Train-Err:0.404 Train-Acc:0.424
# I:0 Test-Err:0.482 Test-Acc:0.7562 Train-Err:0.406 Train-Acc:0.424
# I:0 Test-Err:0.485 Test-Acc:0.7589 Train-Err:0.406 Train-Acc:0.425
# I:0 Test-Err:0.476 Test-Acc:0.7562 Train-Err:0.406 Train-Acc:0.426
# I:0 Test-Err:0.464 Test-Acc:0.7673 Train-Err:0.407 Train-Acc:0.427
# I:0 Test-Err:0.460 Test-Acc:0.7669 Train-Err:0.407 Train-Acc:0.428
# I:0 Test-Err:0.461 Test-Acc:0.7693 Train-Err:0.407 Train-Acc:0.429
# I:0 Test-Err:0.468 Test-Acc:0.7644 Train-Err:0.409 Train-Acc:0.429
# I:0 Test-Err:0.476 Test-Acc:0.757 Train-Err:0.410 Train-Acc:0.43
# I:0 Test-Err:0.462 Test-Acc:0.7456 Train-Err:0.410 Train-Acc:0.431
# I:0 Test-Err:0.462 Test-Acc:0.7455 Train-Err:0.411 Train-Acc:0.431
# I:0 Test-Err:0.462 Test-Acc:0.7441 Train-Err:0.411 Train-Acc:0.432
# I:0 Test-Err:0.455 Test-Acc:0.7471 Train-Err:0.412 Train-Acc:0.433
# I:0 Test-Err:0.447 Test-Acc:0.7457 Train-Err:0.412 Train-Acc:0.434
# I:0 Test-Err:0.449 Test-Acc:0.7391 Train-Err:0.413 Train-Acc:0.435
# I:0 Test-Err:0.445 Test-Acc:0.7428 Train-Err:0.414 Train-Acc:0.435
# I:0 Test-Err:0.459 Test-Acc:0.7509 Train-Err:0.415 Train-Acc:0.435
# I:0 Test-Err:0.458 Test-Acc:0.7514 Train-Err:0.415 Train-Acc:0.436
# I:0 Test-Err:0.455 Test-Acc:0.7623 Train-Err:0.417 Train-Acc:0.436
# I:0 Test-Err:0.434 Test-Acc:0.7937 Train-Err:0.417 Train-Acc:0.437
# I:0 Test-Err:0.413 Test-Acc:0.7896 Train-Err:0.418 Train-Acc:0.437
# I:0 Test-Err:0.488 Test-Acc:0.7198 Train-Err:0.420 Train-Acc:0.438
# I:0 Test-Err:0.488 Test-Acc:0.7205 Train-Err:0.421 Train-Acc:0.438
# I:0 Test-Err:0.492 Test-Acc:0.7303 Train-Err:0.421 Train-Acc:0.439
# I:0 Test-Err:0.491 Test-Acc:0.7272 Train-Err:0.421 Train-Acc:0.44
# I:0 Test-Err:0.495 Test-Acc:0.7214 Train-Err:0.422 Train-Acc:0.441
# I:0 Test-Err:0.496 Test-Acc:0.7246 Train-Err:0.422 Train-Acc:0.442
# I:0 Test-Err:0.492 Test-Acc:0.7376 Train-Err:0.422 Train-Acc:0.443
# I:0 Test-Err:0.492 Test-Acc:0.7377 Train-Err:0.422 Train-Acc:0.444
# I:0 Test-Err:0.494 Test-Acc:0.7297 Train-Err:0.422 Train-Acc:0.445
# I:0 Test-Err:0.454 Test-Acc:0.7891 Train-Err:0.424 Train-Acc:0.445
# I:0 Test-Err:0.453 Test-Acc:0.7896 Train-Err:0.425 Train-Acc:0.445
# I:0 Test-Err:0.439 Test-Acc:0.7994 Train-Err:0.426 Train-Acc:0.445
# I:0 Test-Err:0.437 Test-Acc:0.8 Train-Err:0.426 Train-Acc:0.446
# I:0 Test-Err:0.445 Test-Acc:0.7976 Train-Err:0.427 Train-Acc:0.447
# I:0 Test-Err:0.446 Test-Acc:0.7974 Train-Err:0.427 Train-Acc:0.448
# I:0 Test-Err:0.445 Test-Acc:0.789 Train-Err:0.427 Train-Acc:0.449
# I:0 Test-Err:0.445 Test-Acc:0.7898 Train-Err:0.428 Train-Acc:0.449
# I:0 Test-Err:0.436 Test-Acc:0.7926 Train-Err:0.429 Train-Acc:0.45
# I:0 Test-Err:0.433 Test-Acc:0.7931 Train-Err:0.429 Train-Acc:0.451
# I:0 Test-Err:0.435 Test-Acc:0.7946 Train-Err:0.429 Train-Acc:0.452
# I:0 Test-Err:0.434 Test-Acc:0.7951 Train-Err:0.429 Train-Acc:0.453
# I:0 Test-Err:0.434 Test-Acc:0.7965 Train-Err:0.430 Train-Acc:0.453
# I:0 Test-Err:0.429 Test-Acc:0.7977 Train-Err:0.430 Train-Acc:0.454
# I:0 Test-Err:0.425 Test-Acc:0.7989 Train-Err:0.431 Train-Acc:0.455
# I:0 Test-Err:0.423 Test-Acc:0.7988 Train-Err:0.431 Train-Acc:0.456
# I:0 Test-Err:0.422 Test-Acc:0.7995 Train-Err:0.431 Train-Acc:0.457
# I:0 Test-Err:0.422 Test-Acc:0.7999 Train-Err:0.432 Train-Acc:0.457
# I:0 Test-Err:0.420 Test-Acc:0.7999 Train-Err:0.433 Train-Acc:0.458
# I:0 Test-Err:0.422 Test-Acc:0.8 Train-Err:0.433 Train-Acc:0.459
# I:0 Test-Err:0.423 Test-Acc:0.8006 Train-Err:0.433 Train-Acc:0.46
# I:0 Test-Err:0.425 Test-Acc:0.8002 Train-Err:0.434 Train-Acc:0.461
# I:0 Test-Err:0.421 Test-Acc:0.8 Train-Err:0.434 Train-Acc:0.462
# I:0 Test-Err:0.424 Test-Acc:0.7987 Train-Err:0.435 Train-Acc:0.463
# I:0 Test-Err:0.422 Test-Acc:0.7987 Train-Err:0.436 Train-Acc:0.463
# I:0 Test-Err:0.422 Test-Acc:0.804 Train-Err:0.436 Train-Acc:0.464
# I:0 Test-Err:0.424 Test-Acc:0.8025 Train-Err:0.437 Train-Acc:0.465
# I:0 Test-Err:0.414 Test-Acc:0.8132 Train-Err:0.437 Train-Acc:0.466
# I:0 Test-Err:0.415 Test-Acc:0.8143 Train-Err:0.437 Train-Acc:0.467
# I:0 Test-Err:0.414 Test-Acc:0.7966 Train-Err:0.438 Train-Acc:0.468
# I:0 Test-Err:0.413 Test-Acc:0.7983 Train-Err:0.438 Train-Acc:0.468
# I:0 Test-Err:0.413 Test-Acc:0.7982 Train-Err:0.439 Train-Acc:0.469
# I:0 Test-Err:0.412 Test-Acc:0.803 Train-Err:0.439 Train-Acc:0.469
# I:0 Test-Err:0.413 Test-Acc:0.8032 Train-Err:0.440 Train-Acc:0.47
# I:0 Test-Err:0.412 Test-Acc:0.8045 Train-Err:0.440 Train-Acc:0.471
# I:0 Test-Err:0.413 Test-Acc:0.8012 Train-Err:0.441 Train-Acc:0.472
# I:0 Test-Err:0.408 Test-Acc:0.8057 Train-Err:0.442 Train-Acc:0.472
# I:0 Test-Err:0.408 Test-Acc:0.8032 Train-Err:0.442 Train-Acc:0.473
# I:0 Test-Err:0.409 Test-Acc:0.8015 Train-Err:0.443 Train-Acc:0.474
# I:0 Test-Err:0.405 Test-Acc:0.8063 Train-Err:0.443 Train-Acc:0.474
# I:0 Test-Err:0.406 Test-Acc:0.8046 Train-Err:0.444 Train-Acc:0.475
# I:0 Test-Err:0.406 Test-Acc:0.8047 Train-Err:0.445 Train-Acc:0.475
# I:0 Test-Err:0.407 Test-Acc:0.8092 Train-Err:0.445 Train-Acc:0.476
# I:0 Test-Err:0.408 Test-Acc:0.8095 Train-Err:0.445 Train-Acc:0.477
# I:0 Test-Err:0.407 Test-Acc:0.8099 Train-Err:0.446 Train-Acc:0.478
# I:0 Test-Err:0.410 Test-Acc:0.8163 Train-Err:0.446 Train-Acc:0.479
# I:0 Test-Err:0.405 Test-Acc:0.8121 Train-Err:0.447 Train-Acc:0.48
# I:0 Test-Err:0.396 Test-Acc:0.8058 Train-Err:0.448 Train-Acc:0.48
# I:0 Test-Err:0.401 Test-Acc:0.807 Train-Err:0.448 Train-Acc:0.481
# I:0 Test-Err:0.404 Test-Acc:0.8015 Train-Err:0.449 Train-Acc:0.482
# I:0 Test-Err:0.411 Test-Acc:0.7917 Train-Err:0.449 Train-Acc:0.483
# I:0 Test-Err:0.410 Test-Acc:0.7922 Train-Err:0.449 Train-Acc:0.484
# I:0 Test-Err:0.419 Test-Acc:0.7906 Train-Err:0.450 Train-Acc:0.485
# I:0 Test-Err:0.415 Test-Acc:0.7912 Train-Err:0.450 Train-Acc:0.486
# I:0 Test-Err:0.415 Test-Acc:0.7926 Train-Err:0.450 Train-Acc:0.487
# I:0 Test-Err:0.423 Test-Acc:0.7896 Train-Err:0.450 Train-Acc:0.488
# I:0 Test-Err:0.416 Test-Acc:0.7958 Train-Err:0.451 Train-Acc:0.489
# I:0 Test-Err:0.413 Test-Acc:0.7988 Train-Err:0.451 Train-Acc:0.49
# I:0 Test-Err:0.410 Test-Acc:0.8012 Train-Err:0.451 Train-Acc:0.491
# I:0 Test-Err:0.410 Test-Acc:0.8004 Train-Err:0.451 Train-Acc:0.492
# ...
# I:30 Test-Err:0.547 Test-Acc:0.7182 Train-Err:0.454 Train-Acc:0.527
# I:30 Test-Err:0.541 Test-Acc:0.7196 Train-Err:0.455 Train-Acc:0.527
# I:30 Test-Err:0.559 Test-Acc:0.7091 Train-Err:0.456 Train-Acc:0.527
# I:30 Test-Err:0.543 Test-Acc:0.6801 Train-Err:0.458 Train-Acc:0.527
# I:30 Test-Err:0.543 Test-Acc:0.6835 Train-Err:0.458 Train-Acc:0.528
# I:30 Test-Err:0.538 Test-Acc:0.6871 Train-Err:0.458 Train-Acc:0.529
# I:30 Test-Err:0.504 Test-Acc:0.7249 Train-Err:0.459 Train-Acc:0.53
# I:30 Test-Err:0.507 Test-Acc:0.7227 Train-Err:0.460 Train-Acc:0.53
# I:30 Test-Err:0.481 Test-Acc:0.7582 Train-Err:0.461 Train-Acc:0.53
# I:30 Test-Err:0.471 Test-Acc:0.7558 Train-Err:0.462 Train-Acc:0.53
# I:30 Test-Err:0.729 Test-Acc:0.7095 Train-Err:0.464 Train-Acc:0.531
# I:30 Test-Err:0.726 Test-Acc:0.7022 Train-Err:0.465 Train-Acc:0.532
# I:30 Test-Err:0.725 Test-Acc:0.7016 Train-Err:0.465 Train-Acc:0.533
# I:30 Test-Err:0.732 Test-Acc:0.7046 Train-Err:0.466 Train-Acc:0.533
# I:30 Test-Err:0.810 Test-Acc:0.6524 Train-Err:0.469 Train-Acc:0.534
# I:30 Test-Err:0.811 Test-Acc:0.6526 Train-Err:0.469 Train-Acc:0.535
# I:30 Test-Err:0.807 Test-Acc:0.6348 Train-Err:0.470 Train-Acc:0.536
# I:30 Test-Err:0.807 Test-Acc:0.6303 Train-Err:0.470 Train-Acc:0.537
# I:30 Test-Err:0.797 Test-Acc:0.6327 Train-Err:0.470 Train-Acc:0.538
# I:30 Test-Err:0.747 Test-Acc:0.6878 Train-Err:0.474 Train-Acc:0.538
# I:30 Test-Err:0.694 Test-Acc:0.6913 Train-Err:0.475 Train-Acc:0.539
# I:30 Test-Err:0.628 Test-Acc:0.6895 Train-Err:0.477 Train-Acc:0.539
# I:30 Test-Err:0.637 Test-Acc:0.6871 Train-Err:0.478 Train-Acc:0.54
# I:30 Test-Err:0.641 Test-Acc:0.6881 Train-Err:0.479 Train-Acc:0.54
# I:30 Test-Err:0.635 Test-Acc:0.6835 Train-Err:0.479 Train-Acc:0.541
# I:30 Test-Err:0.635 Test-Acc:0.6828 Train-Err:0.480 Train-Acc:0.541
# I:30 Test-Err:0.576 Test-Acc:0.7435 Train-Err:0.481 Train-Acc:0.541
# I:30 Test-Err:0.576 Test-Acc:0.7455 Train-Err:0.481 Train-Acc:0.542
# I:30 Test-Err:0.576 Test-Acc:0.7456 Train-Err:0.482 Train-Acc:0.543
# I:30 Test-Err:0.568 Test-Acc:0.7463 Train-Err:0.483 Train-Acc:0.544
# I:30 Test-Err:0.567 Test-Acc:0.7469 Train-Err:0.483 Train-Acc:0.545
# I:30 Test-Err:0.568 Test-Acc:0.7466 Train-Err:0.484 Train-Acc:0.545
# I:30 Test-Err:0.571 Test-Acc:0.7432 Train-Err:0.484 Train-Acc:0.546
# I:30 Test-Err:0.568 Test-Acc:0.7435 Train-Err:0.484 Train-Acc:0.547
# I:30 Test-Err:0.553 Test-Acc:0.7439 Train-Err:0.485 Train-Acc:0.548
# I:30 Test-Err:0.555 Test-Acc:0.7403 Train-Err:0.485 Train-Acc:0.549
# I:30 Test-Err:0.556 Test-Acc:0.7426 Train-Err:0.486 Train-Acc:0.549
# I:30 Test-Err:0.556 Test-Acc:0.7431 Train-Err:0.487 Train-Acc:0.549
# I:30 Test-Err:0.553 Test-Acc:0.7423 Train-Err:0.487 Train-Acc:0.55
# I:30 Test-Err:0.552 Test-Acc:0.7422 Train-Err:0.488 Train-Acc:0.551
# I:30 Test-Err:0.546 Test-Acc:0.7428 Train-Err:0.488 Train-Acc:0.552
# I:30 Test-Err:0.548 Test-Acc:0.7397 Train-Err:0.489 Train-Acc:0.553
# I:30 Test-Err:0.544 Test-Acc:0.7408 Train-Err:0.489 Train-Acc:0.554
# I:30 Test-Err:0.537 Test-Acc:0.7414 Train-Err:0.489 Train-Acc:0.555
# I:30 Test-Err:0.524 Test-Acc:0.733 Train-Err:0.492 Train-Acc:0.555
# I:30 Test-Err:0.527 Test-Acc:0.7292 Train-Err:0.492 Train-Acc:0.555
# I:30 Test-Err:0.528 Test-Acc:0.7246 Train-Err:0.492 Train-Acc:0.556
# I:30 Test-Err:0.532 Test-Acc:0.7189 Train-Err:0.494 Train-Acc:0.557
# I:30 Test-Err:0.530 Test-Acc:0.7249 Train-Err:0.494 Train-Acc:0.557
# I:30 Test-Err:0.533 Test-Acc:0.7208 Train-Err:0.494 Train-Acc:0.558
# I:30 Test-Err:0.530 Test-Acc:0.7217 Train-Err:0.495 Train-Acc:0.559
# I:30 Test-Err:0.530 Test-Acc:0.7244 Train-Err:0.495 Train-Acc:0.56
# I:30 Test-Err:0.412 Test-Acc:0.7721 Train-Err:0.499 Train-Acc:0.56
# I:30 Test-Err:0.414 Test-Acc:0.7729 Train-Err:0.499 Train-Acc:0.561
# I:30 Test-Err:0.413 Test-Acc:0.7722 Train-Err:0.499 Train-Acc:0.562
# I:30 Test-Err:0.412 Test-Acc:0.7729 Train-Err:0.500 Train-Acc:0.563
# I:30 Test-Err:0.413 Test-Acc:0.7764 Train-Err:0.500 Train-Acc:0.564
# I:30 Test-Err:0.425 Test-Acc:0.7662 Train-Err:0.500 Train-Acc:0.565
# I:30 Test-Err:0.435 Test-Acc:0.7531 Train-Err:0.501 Train-Acc:0.566
# I:30 Test-Err:0.479 Test-Acc:0.6995 Train-Err:0.502 Train-Acc:0.567
# I:30 Test-Err:0.476 Test-Acc:0.7045 Train-Err:0.502 Train-Acc:0.568
# I:30 Test-Err:0.468 Test-Acc:0.7221 Train-Err:0.503 Train-Acc:0.568
# I:30 Test-Err:0.480 Test-Acc:0.7195 Train-Err:0.504 Train-Acc:0.569
# I:30 Test-Err:0.476 Test-Acc:0.7214 Train-Err:0.504 Train-Acc:0.57
# I:30 Test-Err:0.471 Test-Acc:0.7253 Train-Err:0.504 Train-Acc:0.571
# I:30 Test-Err:0.423 Test-Acc:0.7788 Train-Err:0.505 Train-Acc:0.571
# I:30 Test-Err:0.446 Test-Acc:0.7853 Train-Err:0.506 Train-Acc:0.572
# I:30 Test-Err:0.447 Test-Acc:0.7898 Train-Err:0.507 Train-Acc:0.573
# I:30 Test-Err:0.457 Test-Acc:0.7833 Train-Err:0.507 Train-Acc:0.574
# I:30 Test-Err:0.456 Test-Acc:0.7833 Train-Err:0.508 Train-Acc:0.574
# I:30 Test-Err:0.458 Test-Acc:0.7746 Train-Err:0.508 Train-Acc:0.575
# I:30 Test-Err:0.455 Test-Acc:0.7741 Train-Err:0.509 Train-Acc:0.576
# I:30 Test-Err:0.457 Test-Acc:0.77 Train-Err:0.509 Train-Acc:0.577
# I:30 Test-Err:0.465 Test-Acc:0.7675 Train-Err:0.509 Train-Acc:0.578
# I:30 Test-Err:0.453 Test-Acc:0.779 Train-Err:0.510 Train-Acc:0.578
# I:30 Test-Err:0.443 Test-Acc:0.7762 Train-Err:0.511 Train-Acc:0.579
# I:30 Test-Err:0.444 Test-Acc:0.7758 Train-Err:0.511 Train-Acc:0.58
# I:30 Test-Err:0.445 Test-Acc:0.774 Train-Err:0.512 Train-Acc:0.581
# I:30 Test-Err:0.449 Test-Acc:0.7733 Train-Err:0.512 Train-Acc:0.582
# I:30 Test-Err:0.444 Test-Acc:0.7659 Train-Err:0.512 Train-Acc:0.583
# I:30 Test-Err:0.445 Test-Acc:0.7681 Train-Err:0.512 Train-Acc:0.584
# I:30 Test-Err:0.439 Test-Acc:0.7743 Train-Err:0.513 Train-Acc:0.584
# I:30 Test-Err:0.498 Test-Acc:0.7037 Train-Err:0.514 Train-Acc:0.585
# I:30 Test-Err:0.504 Test-Acc:0.6918 Train-Err:0.515 Train-Acc:0.585
# I:30 Test-Err:0.748 Test-Acc:0.6487 Train-Err:0.518 Train-Acc:0.586
# I:30 Test-Err:0.746 Test-Acc:0.6475 Train-Err:0.519 Train-Acc:0.587
# I:30 Test-Err:0.703 Test-Acc:0.6432 Train-Err:0.519 Train-Acc:0.588
# I:30 Test-Err:0.713 Test-Acc:0.6346 Train-Err:0.520 Train-Acc:0.589
# I:30 Test-Err:0.707 Test-Acc:0.6347 Train-Err:0.520 Train-Acc:0.59
# I:30 Test-Err:0.706 Test-Acc:0.6325 Train-Err:0.520 Train-Acc:0.591
# I:30 Test-Err:0.704 Test-Acc:0.6308 Train-Err:0.521 Train-Acc:0.592
# I:30 Test-Err:0.706 Test-Acc:0.631 Train-Err:0.521 Train-Acc:0.593
# I:30 Test-Err:0.701 Test-Acc:0.6318 Train-Err:0.522 Train-Acc:0.594
# I:30 Test-Err:0.683 Test-Acc:0.6487 Train-Err:0.523 Train-Acc:0.595
# I:30 Test-Err:0.630 Test-Acc:0.7137 Train-Err:0.524 Train-Acc:0.595
# I:30 Test-Err:0.621 Test-Acc:0.7293 Train-Err:0.524 Train-Acc:0.596
# I:30 Test-Err:0.616 Test-Acc:0.7324 Train-Err:0.524 Train-Acc:0.597
# I:30 Test-Err:0.614 Test-Acc:0.7342 Train-Err:0.525 Train-Acc:0.597
# I:30 Test-Err:0.614 Test-Acc:0.7344 Train-Err:0.526 Train-Acc:0.597
# I:30 Test-Err:0.612 Test-Acc:0.7363 Train-Err:0.527 Train-Acc:0.597
# I:30 Test-Err:0.617 Test-Acc:0.7275 Train-Err:0.527 Train-Acc:0.598
# I:30 Test-Err:0.612 Test-Acc:0.7343 Train-Err:0.528 Train-Acc:0.598
# I:30 Test-Err:0.602 Test-Acc:0.7373 Train-Err:0.529 Train-Acc:0.598
# I:30 Test-Err:0.601 Test-Acc:0.7381 Train-Err:0.530 Train-Acc:0.599
# I:30 Test-Err:0.603 Test-Acc:0.7394 Train-Err:0.530 Train-Acc:0.599
# I:30 Test-Err:0.587 Test-Acc:0.7471 Train-Err:0.531 Train-Acc:0.6
# I:30 Test-Err:0.586 Test-Acc:0.747 Train-Err:0.531 Train-Acc:0.601
# I:30 Test-Err:0.621 Test-Acc:0.6825 Train-Err:0.533 Train-Acc:0.601
# I:30 Test-Err:0.617 Test-Acc:0.6825 Train-Err:0.533 Train-Acc:0.602
# I:30 Test-Err:0.617 Test-Acc:0.6815 Train-Err:0.533 Train-Acc:0.603
# I:30 Test-Err:0.612 Test-Acc:0.6824 Train-Err:0.533 Train-Acc:0.604
# I:30 Test-Err:0.612 Test-Acc:0.6824 Train-Err:0.534 Train-Acc:0.604
# I:30 Test-Err:0.615 Test-Acc:0.682 Train-Err:0.534 Train-Acc:0.605
# I:30 Test-Err:0.608 Test-Acc:0.6835 Train-Err:0.535 Train-Acc:0.606
# I:30 Test-Err:0.607 Test-Acc:0.6836 Train-Err:0.536 Train-Acc:0.607
# I:30 Test-Err:0.590 Test-Acc:0.6834 Train-Err:0.536 Train-Acc:0.608
# I:30 Test-Err:0.592 Test-Acc:0.6819 Train-Err:0.536 Train-Acc:0.609
# I:30 Test-Err:0.558 Test-Acc:0.7537 Train-Err:0.537 Train-Acc:0.609
# I:30 Test-Err:0.513 Test-Acc:0.7532 Train-Err:0.539 Train-Acc:0.609
# I:30 Test-Err:0.517 Test-Acc:0.7533 Train-Err:0.540 Train-Acc:0.609
# I:30 Test-Err:0.517 Test-Acc:0.7504 Train-Err:0.540 Train-Acc:0.61
# I:30 Test-Err:0.517 Test-Acc:0.7486 Train-Err:0.540 Train-Acc:0.611
# I:30 Test-Err:0.518 Test-Acc:0.7496 Train-Err:0.541 Train-Acc:0.611
# I:30 Test-Err:0.521 Test-Acc:0.7482 Train-Err:0.542 Train-Acc:0.612
# I:30 Test-Err:0.531 Test-Acc:0.7482 Train-Err:0.542 Train-Acc:0.613
# I:30 Test-Err:0.531 Test-Acc:0.7484 Train-Err:0.543 Train-Acc:0.613
# I:30 Test-Err:0.579 Test-Acc:0.673 Train-Err:0.544 Train-Acc:0.614
# I:30 Test-Err:0.619 Test-Acc:0.6616 Train-Err:0.545 Train-Acc:0.615
# I:30 Test-Err:0.616 Test-Acc:0.6594 Train-Err:0.546 Train-Acc:0.615
# I:30 Test-Err:0.522 Test-Acc:0.7227 Train-Err:0.549 Train-Acc:0.615
# I:30 Test-Err:0.522 Test-Acc:0.7221 Train-Err:0.549 Train-Acc:0.616
# I:30 Test-Err:0.522 Test-Acc:0.7213 Train-Err:0.550 Train-Acc:0.616
# I:30 Test-Err:0.518 Test-Acc:0.724 Train-Err:0.551 Train-Acc:0.617
# I:30 Test-Err:0.577 Test-Acc:0.7048 Train-Err:0.553 Train-Acc:0.618
# I:30 Test-Err:0.599 Test-Acc:0.6866 Train-Err:0.553 Train-Acc:0.619
# I:30 Test-Err:0.600 Test-Acc:0.6847 Train-Err:0.553 Train-Acc:0.62
# I:30 Test-Err:0.580 Test-Acc:0.6941 Train-Err:0.554 Train-Acc:0.62
# I:30 Test-Err:0.577 Test-Acc:0.6951 Train-Err:0.555 Train-Acc:0.62
# I:30 Test-Err:0.574 Test-Acc:0.691 Train-Err:0.556 Train-Acc:0.621
# I:30 Test-Err:0.567 Test-Acc:0.6954 Train-Err:0.556 Train-Acc:0.622
# I:30 Test-Err:0.543 Test-Acc:0.6969 Train-Err:0.556 Train-Acc:0.622
# I:30 Test-Err:0.542 Test-Acc:0.6997 Train-Err:0.558 Train-Acc:0.622
# I:30 Test-Err:0.548 Test-Acc:0.6955 Train-Err:0.558 Train-Acc:0.623
# I:30 Test-Err:0.544 Test-Acc:0.6876 Train-Err:0.559 Train-Acc:0.623
# I:30 Test-Err:0.548 Test-Acc:0.6876 Train-Err:0.559 Train-Acc:0.624
# I:30 Test-Err:0.540 Test-Acc:0.6969 Train-Err:0.560 Train-Acc:0.624
# I:30 Test-Err:0.510 Test-Acc:0.7571 Train-Err:0.561 Train-Acc:0.624
# I:30 Test-Err:0.511 Test-Acc:0.7557 Train-Err:0.562 Train-Acc:0.625
# I:30 Test-Err:0.506 Test-Acc:0.7551 Train-Err:0.562 Train-Acc:0.626
# I:30 Test-Err:0.523 Test-Acc:0.7206 Train-Err:0.563 Train-Acc:0.627
# I:30 Test-Err:0.543 Test-Acc:0.7179 Train-Err:0.565 Train-Acc:0.628
# I:30 Test-Err:0.537 Test-Acc:0.7182 Train-Err:0.566 Train-Acc:0.629
# I:30 Test-Err:0.540 Test-Acc:0.7188 Train-Err:0.566 Train-Acc:0.629
# I:30 Test-Err:0.535 Test-Acc:0.7164 Train-Err:0.567 Train-Acc:0.63
# I:30 Test-Err:0.534 Test-Acc:0.7201 Train-Err:0.567 Train-Acc:0.631
# I:30 Test-Err:0.534 Test-Acc:0.7202 Train-Err:0.568 Train-Acc:0.631
# I:30 Test-Err:0.535 Test-Acc:0.7186 Train-Err:0.568 Train-Acc:0.632
# I:30 Test-Err:0.529 Test-Acc:0.7159 Train-Err:0.568 Train-Acc:0.633
# I:30 Test-Err:0.554 Test-Acc:0.7067 Train-Err:0.570 Train-Acc:0.634
# I:30 Test-Err:0.552 Test-Acc:0.7072 Train-Err:0.570 Train-Acc:0.635
# I:30 Test-Err:0.542 Test-Acc:0.7129 Train-Err:0.571 Train-Acc:0.635
# I:30 Test-Err:0.544 Test-Acc:0.7134 Train-Err:0.571 Train-Acc:0.636
# I:30 Test-Err:0.580 Test-Acc:0.649 Train-Err:0.573 Train-Acc:0.637
# I:30 Test-Err:0.577 Test-Acc:0.6514 Train-Err:0.574 Train-Acc:0.637
# I:30 Test-Err:0.597 Test-Acc:0.6489 Train-Err:0.575 Train-Acc:0.638
# I:30 Test-Err:0.594 Test-Acc:0.6498 Train-Err:0.575 Train-Acc:0.639
# I:30 Test-Err:0.576 Test-Acc:0.6547 Train-Err:0.576 Train-Acc:0.64
# I:30 Test-Err:0.549 Test-Acc:0.7017 Train-Err:0.578 Train-Acc:0.64
# I:30 Test-Err:0.553 Test-Acc:0.7013 Train-Err:0.578 Train-Acc:0.641
# I:30 Test-Err:0.570 Test-Acc:0.6973 Train-Err:0.579 Train-Acc:0.641
# I:30 Test-Err:0.560 Test-Acc:0.7024 Train-Err:0.580 Train-Acc:0.642
# I:30 Test-Err:0.559 Test-Acc:0.7012 Train-Err:0.580 Train-Acc:0.642
# I:30 Test-Err:0.612 Test-Acc:0.6232 Train-Err:0.581 Train-Acc:0.643
# I:30 Test-Err:0.582 Test-Acc:0.7009 Train-Err:0.582 Train-Acc:0.643
# I:30 Test-Err:0.599 Test-Acc:0.658 Train-Err:0.583 Train-Acc:0.644
# I:30 Test-Err:0.584 Test-Acc:0.6806 Train-Err:0.584 Train-Acc:0.644
# I:30 Test-Err:0.574 Test-Acc:0.7214 Train-Err:0.584 Train-Acc:0.645
# I:30 Test-Err:0.575 Test-Acc:0.7205 Train-Err:0.584 Train-Acc:0.646
# I:30 Test-Err:0.555 Test-Acc:0.7279 Train-Err:0.586 Train-Acc:0.646
# I:30 Test-Err:0.551 Test-Acc:0.729 Train-Err:0.586 Train-Acc:0.646
# I:30 Test-Err:0.550 Test-Acc:0.7289 Train-Err:0.586 Train-Acc:0.647
# I:30 Test-Err:0.536 Test-Acc:0.7256 Train-Err:0.587 Train-Acc:0.647
# I:30 Test-Err:0.526 Test-Acc:0.7282 Train-Err:0.588 Train-Acc:0.648
# I:30 Test-Err:0.527 Test-Acc:0.7217 Train-Err:0.588 Train-Acc:0.649
# I:30 Test-Err:0.523 Test-Acc:0.7224 Train-Err:0.588 Train-Acc:0.65
# I:30 Test-Err:0.524 Test-Acc:0.7199 Train-Err:0.589 Train-Acc:0.651
# I:30 Test-Err:0.523 Test-Acc:0.7201 Train-Err:0.590 Train-Acc:0.651
# I:30 Test-Err:0.523 Test-Acc:0.7236 Train-Err:0.590 Train-Acc:0.652
# I:30 Test-Err:0.522 Test-Acc:0.7232 Train-Err:0.590 Train-Acc:0.653
# I:30 Test-Err:0.524 Test-Acc:0.7217 Train-Err:0.590 Train-Acc:0.654
# I:30 Test-Err:0.520 Test-Acc:0.724 Train-Err:0.590 Train-Acc:0.655
# I:30 Test-Err:0.519 Test-Acc:0.7248 Train-Err:0.591 Train-Acc:0.656
# I:30 Test-Err:0.509 Test-Acc:0.7317 Train-Err:0.592 Train-Acc:0.657
# I:30 Test-Err:0.580 Test-Acc:0.7274 Train-Err:0.593 Train-Acc:0.658
# I:30 Test-Err:0.547 Test-Acc:0.7304 Train-Err:0.593 Train-Acc:0.659
# I:30 Test-Err:0.617 Test-Acc:0.6583 Train-Err:0.596 Train-Acc:0.66
# I:30 Test-Err:0.617 Test-Acc:0.6581 Train-Err:0.596 Train-Acc:0.661
# I:30 Test-Err:0.647 Test-Acc:0.5973 Train-Err:0.598 Train-Acc:0.661
# I:30 Test-Err:0.615 Test-Acc:0.657 Train-Err:0.598 Train-Acc:0.661
# I:30 Test-Err:0.628 Test-Acc:0.6264 Train-Err:0.599 Train-Acc:0.661
# I:30 Test-Err:0.629 Test-Acc:0.628 Train-Err:0.600 Train-Acc:0.661
# I:30 Test-Err:0.610 Test-Acc:0.626 Train-Err:0.601 Train-Acc:0.661
# I:30 Test-Err:0.611 Test-Acc:0.626 Train-Err:0.601 Train-Acc:0.662
# I:30 Test-Err:0.598 Test-Acc:0.6307 Train-Err:0.603 Train-Acc:0.662
# I:30 Test-Err:0.577 Test-Acc:0.6407 Train-Err:0.604 Train-Acc:0.662
# I:30 Test-Err:0.577 Test-Acc:0.6401 Train-Err:0.604 Train-Acc:0.663
# I:30 Test-Err:0.569 Test-Acc:0.6393 Train-Err:0.605 Train-Acc:0.663
# I:30 Test-Err:0.565 Test-Acc:0.6473 Train-Err:0.606 Train-Acc:0.664
# I:30 Test-Err:0.559 Test-Acc:0.6486 Train-Err:0.606 Train-Acc:0.665
# I:30 Test-Err:0.577 Test-Acc:0.6483 Train-Err:0.607 Train-Acc:0.666
# I:30 Test-Err:0.575 Test-Acc:0.6483 Train-Err:0.607 Train-Acc:0.667
# I:30 Test-Err:0.575 Test-Acc:0.6533 Train-Err:0.608 Train-Acc:0.667
# I:30 Test-Err:0.566 Test-Acc:0.6582 Train-Err:0.608 Train-Acc:0.668
# I:30 Test-Err:0.592 Test-Acc:0.5918 Train-Err:0.610 Train-Acc:0.668
# I:30 Test-Err:0.659 Test-Acc:0.5799 Train-Err:0.611 Train-Acc:0.669
# I:30 Test-Err:0.640 Test-Acc:0.5717 Train-Err:0.613 Train-Acc:0.669
# I:30 Test-Err:0.620 Test-Acc:0.6425 Train-Err:0.614 Train-Acc:0.669
# I:30 Test-Err:0.629 Test-Acc:0.6416 Train-Err:0.614 Train-Acc:0.67
# I:30 Test-Err:0.627 Test-Acc:0.6416 Train-Err:0.614 Train-Acc:0.671
# I:30 Test-Err:0.614 Test-Acc:0.6403 Train-Err:0.615 Train-Acc:0.671
# I:30 Test-Err:0.605 Test-Acc:0.6458 Train-Err:0.616 Train-Acc:0.671
# I:30 Test-Err:0.609 Test-Acc:0.6435 Train-Err:0.616 Train-Acc:0.672
# I:30 Test-Err:0.614 Test-Acc:0.6371 Train-Err:0.617 Train-Acc:0.672
# I:30 Test-Err:0.620 Test-Acc:0.6349 Train-Err:0.618 Train-Acc:0.673
# I:30 Test-Err:0.613 Test-Acc:0.6428 Train-Err:0.618 Train-Acc:0.674
# I:30 Test-Err:0.613 Test-Acc:0.6428 Train-Err:0.619 Train-Acc:0.674
# I:30 Test-Err:0.614 Test-Acc:0.6444 Train-Err:0.619 Train-Acc:0.675
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_50322/3934138962.py in <module>
#      23             for i in range(len(test_images)):
#      24                 layer_0 = test_images[i:i+1]
# ---> 25                 layer_1 = relu(np.dot(layer_0,weights_0_1))
#      26                 layer_2 = np.dot(layer_1, weights_1_2)
#      27                 test_error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:
