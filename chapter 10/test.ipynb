# %%
import numpy as np, sys
np.random.seed(1)

from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000,28*28) / 255,
                  y_train[0:1000])

x_test = x_test[:100]
y_test = y_test[:100]
one_hot_labels = np.zeros((len(labels),10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

def tanh(x):
    return np.tanh(x)

def tanh2deriv(output):
    return 1 - (output ** 2)

def softmax(x):
    temp = np.exp(x)
    return temp / np.sum(temp, axis=1, keepdims=True)

alpha, iterations = (2, 300)
pixels_per_image, num_labels = (784, 10)
batch_size = 128

input_rows = 28
input_cols = 28

kernel_rows = 3
kernel_cols = 3
num_kernels = 16

hidden_size = ((input_rows - kernel_rows) * 
               (input_cols - kernel_cols)) * num_kernels

weights_0_1 = 0.02*np.random.random((pixels_per_image,hidden_size))-0.01
kernels = 0.02*np.random.random((kernel_rows*kernel_cols,
                                 num_kernels))-0.01

weights_1_2 = 0.2*np.random.random((hidden_size,
                                    num_labels)) - 0.1



def get_image_section(layer,row_from, row_to, col_from, col_to):
    section = layer[:,row_from:row_to,col_from:col_to]
    return section.reshape(-1,1,row_to-row_from, col_to-col_from)

for j in range(iterations):
    correct_cnt = 0
    for i in range(int(len(images) / batch_size)):
        batch_start, batch_end=((i * batch_size),((i+1)*batch_size))
        layer_0 = images[batch_start:batch_end]
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        dropout_mask = np.random.randint(2,size=layer_1.shape)
        layer_1 *= dropout_mask * 2
        layer_2 = softmax(np.dot(layer_1,weights_1_2))

        for k in range(batch_size):
            labelset = labels[batch_start+k:batch_start+k+1]
            _inc = int(np.argmax(layer_2[k:k+1]) == 
                               np.argmax(labelset))
            correct_cnt += _inc

        layer_2_delta = (labels[batch_start:batch_end]-layer_2)\
                        / (batch_size * layer_2.shape[0])
        layer_1_delta = layer_2_delta.dot(weights_1_2.T) * \
                        tanh2deriv(layer_1)
        layer_1_delta *= dropout_mask
        weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
        l1d_reshape = layer_1_delta.reshape(kernel_output.shape)
        k_update = flattened_input.T.dot(l1d_reshape)
        kernels -= alpha * k_update
    
    test_correct_cnt = 0

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
        layer_1 = tanh(np.dot(layer_0,weights_0_1))
        layer_0 = layer_0.reshape(layer_0.shape[0],28,28)
        layer_0.shape

        sects = list()
        for row_start in range(layer_0.shape[1]-kernel_rows):
            for col_start in range(layer_0.shape[2] - kernel_cols):
                sect = get_image_section(layer_0,
                                         row_start,
                                         row_start+kernel_rows,
                                         col_start,
                                         col_start+kernel_cols)
                sects.append(sect)

        expanded_input = np.concatenate(sects,axis=1)
        es = expanded_input.shape
        flattened_input = expanded_input.reshape(es[0]*es[1],-1)

        kernel_output = flattened_input.dot(kernels)
        layer_1 = tanh(kernel_output.reshape(es[0],-1))
        layer_2 = np.dot(layer_1,weights_1_2)

        test_correct_cnt += int(np.argmax(layer_2) == 
                                np.argmax(test_labels[i:i+1]))
    if(j % 1 == 0):
        sys.stdout.write("\n"+ \
         "I:" + str(j) + \
         " Test-Acc:"+str(test_correct_cnt/float(len(test_images)))+\
         " Train-Acc:" + str(correct_cnt/float(len(images))))
# Out:
# I:0 Test-Acc:0.04 Train-Acc:0.056
# I:1 Test-Acc:0.03 Train-Acc:0.04
# I:2 Test-Acc:0.04 Train-Acc:0.033
# I:3 Test-Acc:0.04 Train-Acc:0.044
# I:4 Test-Acc:0.05 Train-Acc:0.042
# I:5 Test-Acc:0.06 Train-Acc:0.058
# I:6 Test-Acc:0.09 Train-Acc:0.068
# I:7 Test-Acc:0.12 Train-Acc:0.084
# I:8 Test-Acc:0.21 Train-Acc:0.109
# I:9 Test-Acc:0.29 Train-Acc:0.136
# I:10 Test-Acc:0.33 Train-Acc:0.179
# I:11 Test-Acc:0.4 Train-Acc:0.208
# I:12 Test-Acc:0.42 Train-Acc:0.211
# I:13 Test-Acc:0.38 Train-Acc:0.235
# I:14 Test-Acc:0.35 Train-Acc:0.26
# I:15 Test-Acc:0.25 Train-Acc:0.211
# I:16 Test-Acc:0.14 Train-Acc:0.14
# I:17 Test-Acc:0.09 Train-Acc:0.046
# I:18 Test-Acc:0.03 Train-Acc:0.032
# I:19 Test-Acc:0.03 Train-Acc:0.02
# I:20 Test-Acc:0.03 Train-Acc:0.021
# I:21 Test-Acc:0.06 Train-Acc:0.041
# I:22 Test-Acc:0.08 Train-Acc:0.069
# I:23 Test-Acc:0.12 Train-Acc:0.089
# I:24 Test-Acc:0.2 Train-Acc:0.12
# I:25 Test-Acc:0.32 Train-Acc:0.178
# I:26 Test-Acc:0.44 Train-Acc:0.219
# I:27 Test-Acc:0.52 Train-Acc:0.252
# I:28 Test-Acc:0.58 Train-Acc:0.326
# I:29 Test-Acc:0.62 Train-Acc:0.339
# I:30 Test-Acc:0.63 Train-Acc:0.368
# I:31 Test-Acc:0.65 Train-Acc:0.394
# I:32 Test-Acc:0.64 Train-Acc:0.393
# I:33 Test-Acc:0.64 Train-Acc:0.431
# I:34 Test-Acc:0.59 Train-Acc:0.413
# I:35 Test-Acc:0.51 Train-Acc:0.398
# I:36 Test-Acc:0.44 Train-Acc:0.325
# I:37 Test-Acc:0.19 Train-Acc:0.213
# I:38 Test-Acc:0.14 Train-Acc:0.127
# I:39 Test-Acc:0.07 Train-Acc:0.073
# I:40 Test-Acc:0.06 Train-Acc:0.06
# I:41 Test-Acc:0.05 Train-Acc:0.04
# I:42 Test-Acc:0.05 Train-Acc:0.04
# I:43 Test-Acc:0.04 Train-Acc:0.032
# I:44 Test-Acc:0.05 Train-Acc:0.044
# I:45 Test-Acc:0.12 Train-Acc:0.062
# I:46 Test-Acc:0.23 Train-Acc:0.099
# I:47 Test-Acc:0.33 Train-Acc:0.151
# I:48 Test-Acc:0.42 Train-Acc:0.185
# I:49 Test-Acc:0.5 Train-Acc:0.195
# I:50 Test-Acc:0.58 Train-Acc:0.237
# I:51 Test-Acc:0.59 Train-Acc:0.271
# I:52 Test-Acc:0.64 Train-Acc:0.329
# I:53 Test-Acc:0.66 Train-Acc:0.353
# I:54 Test-Acc:0.71 Train-Acc:0.42
# I:55 Test-Acc:0.73 Train-Acc:0.432
# I:56 Test-Acc:0.73 Train-Acc:0.453
# I:57 Test-Acc:0.74 Train-Acc:0.495
# I:58 Test-Acc:0.74 Train-Acc:0.494
# I:59 Test-Acc:0.75 Train-Acc:0.5
# I:60 Test-Acc:0.74 Train-Acc:0.52
# I:61 Test-Acc:0.73 Train-Acc:0.523
# I:62 Test-Acc:0.73 Train-Acc:0.525
# I:63 Test-Acc:0.73 Train-Acc:0.551
# I:64 Test-Acc:0.7 Train-Acc:0.548
# I:65 Test-Acc:0.72 Train-Acc:0.493
# I:66 Test-Acc:0.71 Train-Acc:0.517
# I:67 Test-Acc:0.73 Train-Acc:0.508
# I:68 Test-Acc:0.73 Train-Acc:0.499
# I:69 Test-Acc:0.73 Train-Acc:0.502
# I:70 Test-Acc:0.71 Train-Acc:0.504
# I:71 Test-Acc:0.7 Train-Acc:0.479
# I:72 Test-Acc:0.71 Train-Acc:0.481
# I:73 Test-Acc:0.72 Train-Acc:0.475
# I:74 Test-Acc:0.71 Train-Acc:0.455
# I:75 Test-Acc:0.72 Train-Acc:0.477
# I:76 Test-Acc:0.74 Train-Acc:0.493
# I:77 Test-Acc:0.75 Train-Acc:0.528
# I:78 Test-Acc:0.77 Train-Acc:0.533
# I:79 Test-Acc:0.77 Train-Acc:0.555
# I:80 Test-Acc:0.78 Train-Acc:0.584
# I:81 Test-Acc:0.79 Train-Acc:0.588
# I:82 Test-Acc:0.8 Train-Acc:0.601
# I:83 Test-Acc:0.78 Train-Acc:0.608
# I:84 Test-Acc:0.8 Train-Acc:0.622
# I:85 Test-Acc:0.8 Train-Acc:0.621
# I:86 Test-Acc:0.79 Train-Acc:0.646
# I:87 Test-Acc:0.84 Train-Acc:0.627
# I:88 Test-Acc:0.84 Train-Acc:0.643
# I:89 Test-Acc:0.82 Train-Acc:0.656
# I:90 Test-Acc:0.81 Train-Acc:0.666
# I:91 Test-Acc:0.83 Train-Acc:0.674
# I:92 Test-Acc:0.83 Train-Acc:0.671
# I:93 Test-Acc:0.83 Train-Acc:0.67
# I:94 Test-Acc:0.83 Train-Acc:0.69
# I:95 Test-Acc:0.84 Train-Acc:0.684
# I:96 Test-Acc:0.83 Train-Acc:0.686
# I:97 Test-Acc:0.83 Train-Acc:0.68
# I:98 Test-Acc:0.84 Train-Acc:0.687
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_23081/1583259000.py in <module>
#      99         weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
#     100         l1d_reshape = layer_1_delta.reshape(kernel_output.shape)
# --> 101         k_update = flattened_input.T.dot(l1d_reshape)
#     102         kernels -= alpha * k_update
#     103
#
# KeyboardInterrupt:
